# %% [markdown]
# # 0. Connect to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 1. Installation for Protenix and AFMFold

# %% [markdown]
# ## 1.a Install Protenix

# %%
# !pip3 install protenix
# Out:
# Requirement already satisfied: protenix in /usr/local/lib/python3.12/dist-packages (0.7.3)
# Requirement already satisfied: torch==2.7.1 in /usr/local/lib/python3.12/dist-packages (from protenix) (2.7.1)
# Requirement already satisfied: torchvision==0.22.1 in /usr/local/lib/python3.12/dist-packages (from protenix) (0.22.1)
# Requirement already satisfied: torchaudio==2.7.1 in /usr/local/lib/python3.12/dist-packages (from protenix) (2.7.1)
# Requirement already satisfied: cuequivariance-ops-torch-cu12==0.6.1 in /usr/local/lib/python3.12/dist-packages (from protenix) (0.6.1)
# Requirement already satisfied: cuequivariance-torch==0.6.1 in /usr/local/lib/python3.12/dist-packages (from protenix) (0.6.1)
# Requirement already satisfied: scipy>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from protenix) (1.16.3)
# Requirement already satisfied: ml_collections==1.1.0 in /usr/local/lib/python3.12/dist-packages (from protenix) (1.1.0)
# Requirement already satisfied: tqdm==4.67.1 in /usr/local/lib/python3.12/dist-packages (from protenix) (4.67.1)
# Requirement already satisfied: pandas==2.3.1 in /usr/local/lib/python3.12/dist-packages (from protenix) (2.3.1)
# Requirement already satisfied: dm-tree==0.1.9 in /usr/local/lib/python3.12/dist-packages (from protenix) (0.1.9)
# Requirement already satisfied: PyYAML==6.0.2 in /usr/local/lib/python3.12/dist-packages (from protenix) (6.0.2)
# Requirement already satisfied: matplotlib==3.10.5 in /usr/local/lib/python3.12/dist-packages (from protenix) (3.10.5)
# Requirement already satisfied: ipywidgets==8.1.7 in /usr/local/lib/python3.12/dist-packages (from protenix) (8.1.7)
# Requirement already satisfied: py3Dmol==2.5.2 in /usr/local/lib/python3.12/dist-packages (from protenix) (2.5.2)
# Requirement already satisfied: rdkit==2023.9.6 in /usr/local/lib/python3.12/dist-packages (from protenix) (2023.9.6)
# Requirement already satisfied: biopython==1.85 in /usr/local/lib/python3.12/dist-packages (from protenix) (1.85)
# Requirement already satisfied: biotite==1.4.0 in /usr/local/lib/python3.12/dist-packages (from protenix) (1.4.0)
# Requirement already satisfied: modelcif==1.4 in /usr/local/lib/python3.12/dist-packages (from protenix) (1.4)
# Requirement already satisfied: gemmi==0.6.7 in /usr/local/lib/python3.12/dist-packages (from protenix) (0.6.7)
# Requirement already satisfied: pdbeccdutils==0.8.6 in /usr/local/lib/python3.12/dist-packages (from protenix) (0.8.6)
# Requirement already satisfied: fair-esm==2.0.0 in /usr/local/lib/python3.12/dist-packages (from protenix) (2.0.0)
# Requirement already satisfied: scikit-learn==1.7.1 in /usr/local/lib/python3.12/dist-packages (from protenix) (1.7.1)
# Requirement already satisfied: scikit-learn-extra==0.3.0 in /usr/local/lib/python3.12/dist-packages (from protenix) (0.3.0)
# Requirement already satisfied: deepspeed==0.17.5 in /usr/local/lib/python3.12/dist-packages (from protenix) (0.17.5)
# Requirement already satisfied: pydantic>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from protenix) (2.12.3)
# Requirement already satisfied: triton==3.3.1 in /usr/local/lib/python3.12/dist-packages (from protenix) (3.3.1)
# Requirement already satisfied: optree==0.17.0 in /usr/local/lib/python3.12/dist-packages (from protenix) (0.17.0)
# Requirement already satisfied: protobuf==6.31.1 in /usr/local/lib/python3.12/dist-packages (from protenix) (6.31.1)
# Requirement already satisfied: icecream==2.1.7 in /usr/local/lib/python3.12/dist-packages (from protenix) (2.1.7)
# Requirement already satisfied: ipdb==0.13.13 in /usr/local/lib/python3.12/dist-packages (from protenix) (0.13.13)
# Requirement already satisfied: wandb==0.21.1 in /usr/local/lib/python3.12/dist-packages (from protenix) (0.21.1)
# Requirement already satisfied: posix_ipc==1.3.0 in /usr/local/lib/python3.12/dist-packages (from protenix) (1.3.0)
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.12/dist-packages (from protenix) (1.26.4)
# Requirement already satisfied: biotraj<2.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from biotite==1.4.0->protenix) (1.2.2)
# Requirement already satisfied: msgpack>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from biotite==1.4.0->protenix) (1.1.2)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.12/dist-packages (from biotite==1.4.0->protenix) (3.6.1)
# Requirement already satisfied: packaging>=24.0 in /usr/local/lib/python3.12/dist-packages (from biotite==1.4.0->protenix) (25.0)
# Requirement already satisfied: requests>=2.12 in /usr/local/lib/python3.12/dist-packages (from biotite==1.4.0->protenix) (2.32.4)
# Requirement already satisfied: cuequivariance-ops-cu12==0.6.1 in /usr/local/lib/python3.12/dist-packages (from cuequivariance-ops-torch-cu12==0.6.1->protenix) (0.6.1)
# Requirement already satisfied: cuequivariance in /usr/local/lib/python3.12/dist-packages (from cuequivariance-torch==0.6.1->protenix) (0.8.1)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.17.5->protenix) (0.8.2)
# Requirement already satisfied: hjson in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.17.5->protenix) (3.1.0)
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.17.5->protenix) (1.13.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.17.5->protenix) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.17.5->protenix) (9.0.0)
# Requirement already satisfied: nvidia-ml-py in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.17.5->protenix) (13.590.48)
# Requirement already satisfied: absl-py>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from dm-tree==0.1.9->protenix) (1.4.0)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.12/dist-packages (from dm-tree==0.1.9->protenix) (25.4.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.12/dist-packages (from dm-tree==0.1.9->protenix) (2.0.1)
# Requirement already satisfied: colorama>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from icecream==2.1.7->protenix) (0.4.6)
# Requirement already satisfied: pygments>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from icecream==2.1.7->protenix) (2.19.2)
# Requirement already satisfied: executing>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from icecream==2.1.7->protenix) (2.2.1)
# Requirement already satisfied: asttokens>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from icecream==2.1.7->protenix) (3.0.1)
# Requirement already satisfied: ipython>=7.31.1 in /usr/local/lib/python3.12/dist-packages (from ipdb==0.13.13->protenix) (7.34.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipdb==0.13.13->protenix) (4.4.2)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from ipywidgets==8.1.7->protenix) (0.2.3)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets==8.1.7->protenix) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /usr/local/lib/python3.12/dist-packages (from ipywidgets==8.1.7->protenix) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /usr/local/lib/python3.12/dist-packages (from ipywidgets==8.1.7->protenix) (3.0.16)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.5->protenix) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.5->protenix) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.5->protenix) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.5->protenix) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.5->protenix) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.5->protenix) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.5->protenix) (2.9.0.post0)
# Requirement already satisfied: ihm>=2.6 in /usr/local/lib/python3.12/dist-packages (from modelcif==1.4->protenix) (2.9)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from optree==0.17.0->protenix) (4.15.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas==2.3.1->protenix) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas==2.3.1->protenix) (2025.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.7.1->protenix) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.7.1->protenix) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.7.1->protenix) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.7.1->protenix) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.7.1->protenix) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.7.1->protenix) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.7.1->protenix) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.7.1->protenix) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.7.1->protenix) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch==2.7.1->protenix) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /usr/local/lib/python3.12/dist-packages (from torch==2.7.1->protenix) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.7.1->protenix) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch==2.7.1->protenix) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.7.1->protenix) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.7.1->protenix) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.7.1->protenix) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.7.1->protenix) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /usr/local/lib/python3.12/dist-packages (from torch==2.7.1->protenix) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch==2.7.1->protenix) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch==2.7.1->protenix) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch==2.7.1->protenix) (1.11.1.6)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.12/dist-packages (from wandb==0.21.1->protenix) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.21.1->protenix) (3.1.46)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb==0.21.1->protenix) (4.5.1)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb==0.21.1->protenix) (2.50.0)
# Requirement already satisfied: pynvml in /usr/local/lib/python3.12/dist-packages (from cuequivariance-ops-cu12==0.6.1->cuequivariance-ops-torch-cu12==0.6.1->protenix) (13.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->protenix) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->protenix) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->protenix) (0.4.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb==0.21.1->protenix) (4.0.12)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->protenix) (0.19.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->protenix) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->protenix) (3.0.52)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->protenix) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->protenix) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.31.1->ipdb==0.13.13->protenix) (4.9.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib==3.10.5->protenix) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.12->biotite==1.4.0->protenix) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.12->biotite==1.4.0->protenix) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.12->biotite==1.4.0->protenix) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.12->biotite==1.4.0->protenix) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.7.1->protenix) (1.3.0)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.12/dist-packages (from cuequivariance->cuequivariance-torch==0.6.1->protenix) (3.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.7.1->protenix) (3.0.3)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb==0.21.1->protenix) (5.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.31.1->ipdb==0.13.13->protenix) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=7.31.1->ipdb==0.13.13->protenix) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.31.1->ipdb==0.13.13->protenix) (0.4.0)

# %% [markdown]
# ## 1.b Install AFMFold from the repo stored in Google Drive

# %%
cd /content/drive/My Drive/colab_cache/afmfold
# Out:
# /content/drive/My Drive/colab_cache/afmfold

# %%
# !pip install -e .[e2cnn]
# !pip install openmm
# Out:
# Obtaining file:///content/drive/My%20Drive/colab_cache/afmfold
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from afmfold==0.1.0) (6.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from afmfold==0.1.0) (1.16.3)
# Requirement already satisfied: ml_collections in /usr/local/lib/python3.12/dist-packages (from afmfold==0.1.0) (1.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from afmfold==0.1.0) (4.67.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from afmfold==0.1.0) (2.3.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from afmfold==0.1.0) (0.17.0)
# Requirement already satisfied: rdkit in /usr/local/lib/python3.12/dist-packages (from afmfold==0.1.0) (2023.9.6)
# Collecting biopython==1.83 (from afmfold==0.1.0)
#   Downloading biopython-1.83-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting modelcif==0.7 (from afmfold==0.1.0)
#   Downloading modelcif-0.7.tar.gz (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 5.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting biotite==1.0.1 (from afmfold==0.1.0)
#   Downloading biotite-1.0.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.2 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from afmfold==0.1.0) (1.7.1)
# Requirement already satisfied: scikit-learn-extra in /usr/local/lib/python3.12/dist-packages (from afmfold==0.1.0) (0.3.0)
# Collecting deepspeed==0.16.7 (from afmfold==0.1.0)
#   Downloading deepspeed-0.16.7.tar.gz (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 82.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting protobuf==3.20.2 (from afmfold==0.1.0)
#   Downloading protobuf-3.20.2-py2.py3-none-any.whl.metadata (720 bytes)
# Requirement already satisfied: icecream in /usr/local/lib/python3.12/dist-packages (from afmfold==0.1.0) (2.1.7)
# Requirement already satisfied: ipdb in /usr/local/lib/python3.12/dist-packages (from afmfold==0.1.0) (0.13.13)
# Requirement already satisfied: wandb in /usr/local/lib/python3.12/dist-packages (from afmfold==0.1.0) (0.21.1)
# Collecting numpy==1.26.3 (from afmfold==0.1.0)
#   Downloading numpy-1.26.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 6.0 MB/s eta 0:00:00
# Collecting matplotlib==3.10.1 (from afmfold==0.1.0)
#   Downloading matplotlib-3.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from afmfold==0.1.0) (8.1.7)
# Requirement already satisfied: py3Dmol in /usr/local/lib/python3.12/dist-packages (from afmfold==0.1.0) (2.5.2)
# Requirement already satisfied: nvidia-cublas-cu12 in /usr/local/lib/python3.12/dist-packages (from afmfold==0.1.0) (12.6.4.1)
# Collecting torch==2.3.1 (from afmfold==0.1.0)
#   Downloading torch-2.3.1-cp312-cp312-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting mdtraj==1.9.9 (from afmfold==0.1.0)
#   Downloading mdtraj-1.9.9.tar.gz (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 96.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting scikit-image==0.24.0 (from afmfold==0.1.0)
#   Downloading scikit_image-0.24.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting shapely<2.1,>=2.0 (from afmfold==0.1.0)
#   Downloading shapely-2.0.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting pyproj<3.7,>=3.6 (from afmfold==0.1.0)
#   Downloading pyproj-3.6.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting cartopy<0.24,>=0.23 (from afmfold==0.1.0)
#   Downloading Cartopy-0.23.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.0 kB)
# Requirement already satisfied: biotraj<2.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from biotite==1.0.1->afmfold==0.1.0) (1.2.2)
# Requirement already satisfied: msgpack>=0.5.6 in /usr/local/lib/python3.12/dist-packages (from biotite==1.0.1->afmfold==0.1.0) (1.1.2)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.12/dist-packages (from biotite==1.0.1->afmfold==0.1.0) (3.6.1)
# Requirement already satisfied: requests>=2.12 in /usr/local/lib/python3.12/dist-packages (from biotite==1.0.1->afmfold==0.1.0) (2.32.4)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.16.7->afmfold==0.1.0) (0.8.1)
# Requirement already satisfied: hjson in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.16.7->afmfold==0.1.0) (3.1.0)
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.16.7->afmfold==0.1.0) (1.13.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.16.7->afmfold==0.1.0) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.16.7->afmfold==0.1.0) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.16.7->afmfold==0.1.0) (9.0.0)
# Requirement already satisfied: pydantic>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.16.7->afmfold==0.1.0) (2.12.3)
# Requirement already satisfied: nvidia-ml-py in /usr/local/lib/python3.12/dist-packages (from deepspeed==0.16.7->afmfold==0.1.0) (13.590.44)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->afmfold==0.1.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->afmfold==0.1.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->afmfold==0.1.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->afmfold==0.1.0) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->afmfold==0.1.0) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->afmfold==0.1.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.10.1->afmfold==0.1.0) (2.9.0.post0)
# Requirement already satisfied: astunparse in /usr/local/lib/python3.12/dist-packages (from mdtraj==1.9.9->afmfold==0.1.0) (1.6.3)
# Requirement already satisfied: ihm>=0.34 in /usr/local/lib/python3.12/dist-packages (from modelcif==0.7->afmfold==0.1.0) (2.8)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image==0.24.0->afmfold==0.1.0) (2.37.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image==0.24.0->afmfold==0.1.0) (2025.12.12)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image==0.24.0->afmfold==0.1.0) (0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.3.1->afmfold==0.1.0) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.3.1->afmfold==0.1.0) (4.15.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from torch==2.3.1->afmfold==0.1.0) (1.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.3.1->afmfold==0.1.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.3.1->afmfold==0.1.0) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.3.1->afmfold==0.1.0)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.3.1->afmfold==0.1.0)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.3.1->afmfold==0.1.0)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.3.1->afmfold==0.1.0)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12 (from afmfold==0.1.0)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.3.1->afmfold==0.1.0)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.3.1->afmfold==0.1.0)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.3.1->afmfold==0.1.0)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.3.1->afmfold==0.1.0)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch==2.3.1->afmfold==0.1.0)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.3.1->afmfold==0.1.0)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.12/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.1->afmfold==0.1.0) (12.6.85)
# Collecting e2cnn@ git+https://github.com/QUVA-Lab/e2cnn.git (from afmfold==0.1.0)
#   Cloning https://github.com/QUVA-Lab/e2cnn.git to /tmp/pip-install-t3d27l5u/e2cnn_7a27c50982ce499a8f8607f865930d26
#   Running command git clone --filter=blob:none --quiet https://github.com/QUVA-Lab/e2cnn.git /tmp/pip-install-t3d27l5u/e2cnn_7a27c50982ce499a8f8607f865930d26
#   Resolved https://github.com/QUVA-Lab/e2cnn.git to commit 022d6ca4a78ab666f3c149d1849e324ed1d40238
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyshp>=2.3 in /usr/local/lib/python3.12/dist-packages (from cartopy<0.24,>=0.23->afmfold==0.1.0) (3.0.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyproj<3.7,>=3.6->afmfold==0.1.0) (2025.11.12)
# Requirement already satisfied: colorama>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from icecream->afmfold==0.1.0) (0.4.6)
# Requirement already satisfied: pygments>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from icecream->afmfold==0.1.0) (2.19.2)
# Requirement already satisfied: executing>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from icecream->afmfold==0.1.0) (2.2.1)
# Requirement already satisfied: asttokens>=2.0.1 in /usr/local/lib/python3.12/dist-packages (from icecream->afmfold==0.1.0) (3.0.1)
# Requirement already satisfied: ipython>=7.31.1 in /usr/local/lib/python3.12/dist-packages (from ipdb->afmfold==0.1.0) (7.34.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipdb->afmfold==0.1.0) (4.4.2)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->afmfold==0.1.0) (0.2.3)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->afmfold==0.1.0) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->afmfold==0.1.0) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->afmfold==0.1.0) (3.0.16)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from ml_collections->afmfold==0.1.0) (1.4.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->afmfold==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->afmfold==0.1.0) (2025.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->afmfold==0.1.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->afmfold==0.1.0) (3.6.0)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.12/dist-packages (from wandb->afmfold==0.1.0) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->afmfold==0.1.0) (3.1.45)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from wandb->afmfold==0.1.0) (4.5.1)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from wandb->afmfold==0.1.0) (2.47.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->afmfold==0.1.0) (4.0.12)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.31.1->ipdb->afmfold==0.1.0) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.31.1->ipdb->afmfold==0.1.0) (0.19.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.31.1->ipdb->afmfold==0.1.0) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.31.1->ipdb->afmfold==0.1.0) (3.0.52)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.31.1->ipdb->afmfold==0.1.0) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython>=7.31.1->ipdb->afmfold==0.1.0) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.31.1->ipdb->afmfold==0.1.0) (4.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->deepspeed==0.16.7->afmfold==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->deepspeed==0.16.7->afmfold==0.1.0) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0.0->deepspeed==0.16.7->afmfold==0.1.0) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib==3.10.1->afmfold==0.1.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.12->biotite==1.0.1->afmfold==0.1.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.12->biotite==1.0.1->afmfold==0.1.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.12->biotite==1.0.1->afmfold==0.1.0) (2.5.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse->mdtraj==1.9.9->afmfold==0.1.0) (0.45.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.3.1->afmfold==0.1.0) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->torch==2.3.1->afmfold==0.1.0) (1.3.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->afmfold==0.1.0) (5.0.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.31.1->ipdb->afmfold==0.1.0) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=7.31.1->ipdb->afmfold==0.1.0) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.31.1->ipdb->afmfold==0.1.0) (0.2.14)
# Downloading biopython-1.83-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 109.7 MB/s eta 0:00:00
# Downloading biotite-1.0.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.8/36.8 MB 64.6 MB/s eta 0:00:00
# Downloading matplotlib-3.10.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 124.8 MB/s eta 0:00:00
# Downloading numpy-1.26.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 113.4 MB/s eta 0:00:00
# Downloading protobuf-3.20.2-py2.py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 17.0 MB/s eta 0:00:00
# Downloading scikit_image-0.24.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.0/15.0 MB 132.1 MB/s eta 0:00:00
# Downloading torch-2.3.1-cp312-cp312-manylinux1_x86_64.whl (779.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 6.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 90.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 105.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 62.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 20.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 43.5 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 20.3 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 12.5 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 14.7 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 11.0 MB/s eta 0:00:00
# Downloading Cartopy-0.23.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 27.1 MB/s eta 0:00:00
# Downloading pyproj-3.6.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 140.9 MB/s eta 0:00:00
# Downloading shapely-2.0.7-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 106.5 MB/s eta 0:00:00
# Building wheels for collected packages: afmfold, deepspeed, mdtraj, modelcif, e2cnn
#   Building editable for afmfold (pyproject.toml) ... done
#   Created wheel for afmfold: filename=afmfold-0.1.0-0.editable-py3-none-any.whl size=4558 sha256=31d20a8ac9c9086c4fb17f1146060658d27a1a80f889625602b8953d4796684a
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hpihk9l0/wheels/ff/19/f4/c9fe3b40f29a40f7ce37dab7dc92e4e8749ac552a6cb38ef85
#   Building wheel for deepspeed (setup.py) ... done
#   Created wheel for deepspeed: filename=deepspeed-0.16.7-py3-none-any.whl size=1642800 sha256=817180e10439070227b2d66866ed1a242ae485c4f20eb0eaadc5570d1debe957
#   Stored in directory: /root/.cache/pip/wheels/38/e6/3b/12a17aa5bf1b87db0863a834a21f2e4d9434455f423849042f
#   Building wheel for mdtraj (pyproject.toml) ... done
#   Created wheel for mdtraj: filename=mdtraj-1.9.9-cp312-cp312-linux_x86_64.whl size=7981870 sha256=6403d40929309607bde6ba3e9c3ff621cc0822cc5562c8813ddf1dbb7d8de8b7
#   Stored in directory: /root/.cache/pip/wheels/68/5d/1a/d382b563e5bba56f173ee1a2ada616a04060171475d03fff0d
#   Building wheel for modelcif (setup.py) ... done
#   Created wheel for modelcif: filename=modelcif-0.7-py3-none-any.whl size=36633 sha256=bb25445c08f1bb7a9e36638537603e9e4e7dfae713e17c61508d914665b1360f
#   Stored in directory: /root/.cache/pip/wheels/5a/5e/5e/5eeaf24c134dcec7882101af3fd60bddd71ac803bd92c552fd
#   Building wheel for e2cnn (setup.py) ... done
#   Created wheel for e2cnn: filename=e2cnn-0.2.3-py3-none-any.whl size=225262 sha256=87c1f1b22f653de3b7f4e192b7d0a78241d841583f0dde701470e02d2c84d99f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hpihk9l0/wheels/47/35/a8/632d9c76d638acd0dcc15cddf536ddf2668bb112e349fe78af
# Successfully built afmfold deepspeed mdtraj modelcif e2cnn
# Installing collected packages: pyproj, protobuf, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, shapely, nvidia-cusolver-cu12, nvidia-cudnn-cu12, modelcif, biopython, torch, scikit-image, mdtraj, matplotlib, e2cnn, deepspeed, cartopy, biotite, afmfold
#   Attempting uninstall: pyproj
#     Found existing installation: pyproj 3.7.2
#     Uninstalling pyproj-3.7.2:
#       Successfully uninstalled pyproj-3.7.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 6.31.1
#     Uninstalling protobuf-6.31.1:
#       Successfully uninstalled protobuf-6.31.1
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.6.77
#     Uninstalling nvidia-nvtx-cu12-12.6.77:
#       Successfully uninstalled nvidia-nvtx-cu12-12.6.77
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.26.2
#     Uninstalling nvidia-nccl-cu12-2.26.2:
#       Successfully uninstalled nvidia-nccl-cu12-2.26.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.4.2
#     Uninstalling nvidia-cusparse-cu12-12.5.4.2:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.4.2
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.7.77
#     Uninstalling nvidia-curand-cu12-10.3.7.77:
#       Successfully uninstalled nvidia-curand-cu12-10.3.7.77
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.3.0.4
#     Uninstalling nvidia-cufft-cu12-11.3.0.4:
#       Successfully uninstalled nvidia-cufft-cu12-11.3.0.4
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.6.77
#     Uninstalling nvidia-cuda-runtime-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.6.77
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.6.77:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.6.77
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.6.80
#     Uninstalling nvidia-cuda-cupti-cu12-12.6.80:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.6.80
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.6.4.1
#     Uninstalling nvidia-cublas-cu12-12.6.4.1:
#       Successfully uninstalled nvidia-cublas-cu12-12.6.4.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: shapely
#     Found existing installation: shapely 2.1.2
#     Uninstalling shapely-2.1.2:
#       Successfully uninstalled shapely-2.1.2
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.7.1.2
#     Uninstalling nvidia-cusolver-cu12-11.7.1.2:
#       Successfully uninstalled nvidia-cusolver-cu12-11.7.1.2
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.5.1.17
#     Uninstalling nvidia-cudnn-cu12-9.5.1.17:
#       Successfully uninstalled nvidia-cudnn-cu12-9.5.1.17
#   Attempting uninstall: modelcif
#     Found existing installation: modelcif 1.4
#     Uninstalling modelcif-1.4:
#       Successfully uninstalled modelcif-1.4
#   Attempting uninstall: biopython
#     Found existing installation: biopython 1.85
#     Uninstalling biopython-1.85:
#       Successfully uninstalled biopython-1.85
#   Attempting uninstall: torch
#     Found existing installation: torch 2.7.1
#     Uninstalling torch-2.7.1:
#       Successfully uninstalled torch-2.7.1
#   Attempting uninstall: scikit-image
#     Found existing installation: scikit-image 0.25.2
#     Uninstalling scikit-image-0.25.2:
#       Successfully uninstalled scikit-image-0.25.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.5
#     Uninstalling matplotlib-3.10.5:
#       Successfully uninstalled matplotlib-3.10.5
#   Attempting uninstall: deepspeed
#     Found existing installation: deepspeed 0.17.5
#     Uninstalling deepspeed-0.17.5:
#       Successfully uninstalled deepspeed-0.17.5
#   Attempting uninstall: biotite
#     Found existing installation: biotite 1.4.0
#     Uninstalling biotite-1.4.0:
#       Successfully uninstalled biotite-1.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cuequivariance-ops-cu12 0.6.1 requires nvidia-cublas-cu12>=12.5.0, but you have nvidia-cublas-cu12 12.1.3.1 which is incompatible.
# torchvision 0.22.1 requires torch==2.7.1, but you have torch 2.3.1 which is incompatible.
# torchaudio 2.7.1 requires torch==2.7.1, but you have torch 2.3.1 which is incompatible.
# protenix 0.7.3 requires biopython==1.85, but you have biopython 1.83 which is incompatible.
# protenix 0.7.3 requires biotite==1.4.0, but you have biotite 1.0.1 which is incompatible.
# protenix 0.7.3 requires deepspeed==0.17.5, but you have deepspeed 0.16.7 which is incompatible.
# protenix 0.7.3 requires matplotlib==3.10.5, but you have matplotlib 3.10.1 which is incompatible.
# protenix 0.7.3 requires modelcif==1.4, but you have modelcif 0.7 which is incompatible.
# protenix 0.7.3 requires numpy==1.26.4, but you have numpy 1.26.3 which is incompatible.
# protenix 0.7.3 requires protobuf==6.31.1, but you have protobuf 3.20.2 which is incompatible.
# protenix 0.7.3 requires torch==2.7.1, but you have torch 2.3.1 which is incompatible.
# pdbeccdutils 0.8.6 requires numpy<1.27.0,>=1.26.4, but you have numpy 1.26.3 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.1 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.3 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.3 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.3 which is incompatible.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.3 which is incompatible.
# opentelemetry-proto 1.37.0 requires protobuf<7.0,>=5.0, but you have protobuf 3.20.2 which is incompatible.
# spopt 0.7.0 requires shapely>=2.1.0, but you have shapely 2.0.7 which is incompatible.
# music21 9.9.1 requires numpy>=1.26.4, but you have numpy 1.26.3 which is incompatible.
# esda 2.8.0 requires shapely>=2.1, but you have shapely 2.0.7 which is incompatible.
# pytensor 2.35.1 requires numpy>=2.0, but you have numpy 1.26.3 which is incompatible.
# tensorflow-metadata 1.17.2 requires protobuf>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.2 which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 3.20.2 which is incompatible.
# tensorflow 2.19.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3, but you have protobuf 3.20.2 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.3 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.3 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.2 which is incompatible.
# Successfully installed afmfold-0.1.0 biopython-1.83 biotite-1.0.1 cartopy-0.23.0 deepspeed-0.16.7 e2cnn-0.2.3 matplotlib-3.10.1 mdtraj-1.9.9 modelcif-0.7 numpy-1.26.3 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvtx-cu12-12.1.105 protobuf-3.20.2 pyproj-3.6.1 scikit-image-0.24.0 shapely-2.0.7 torch-2.3.1
# Collecting openmm
#   Downloading openmm-8.4.0.post2-cp312-cp312-manylinux_2_34_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from openmm) (1.26.3)
# Downloading openmm-8.4.0.post2-cp312-cp312-manylinux_2_34_x86_64.whl (14.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 93.6 MB/s eta 0:00:00
# Installing collected packages: openmm
# Successfully installed openmm-8.4.0.post2

# %%
# Check that they are both installed
# !which afmfold
# !which protenix
# Out:
# /usr/local/bin/afmfold
# /usr/local/bin/protenix

# %%
cd /content/
# Out:
# /content

# %% [markdown]
# ## 1.c [Optional] Download Protenix component files if necessary

# %%
# !mkdir -p /usr/local/lib/python3.12/dist-packages/release_data/ccd_cache
# !cp /content/drive/MyDrive/colab_cache/afmfold/src/afmfold/release_data/ccd_cache/components.v20240608.cif /usr/local/lib/python3.12/dist-packages/release_data/ccd_cache/.

# %%
# !python /content/drive/MyDrive/colab_cache/afmfold/src/afmfold/scripts/gen_ccd_cache.py -n 24
# Out:
# --2026-01-29 20:07:03--  https://files.wwpdb.org/pub/pdb/data/monomers/components.cif.gz
# Resolving files.wwpdb.org (files.wwpdb.org)... 65.9.86.84, 65.9.86.43, 65.9.86.31, ...
# Connecting to files.wwpdb.org (files.wwpdb.org)|65.9.86.84|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 113846299 (109M) [application/gzip]
# Saving to: ‘/content/drive/MyDrive/colab_cache/afmfold/src/afmfold/release_data/ccd_cache/components.cif.gz’
#
# components.cif.gz   100%[===================>] 108.57M  26.8MB/s    in 5.0s
#
# 2026-01-29 20:07:09 (21.7 MB/s) - ‘/content/drive/MyDrive/colab_cache/afmfold/src/afmfold/release_data/ccd_cache/components.cif.gz’ saved [113846299/113846299]
#
#   0% 56/49282 [00:01<15:14, 53.81it/s][20:07:35] UFFTYPER: Warning: hybridization set to SP3 for atom 9
#   0% 173/49282 [00:02<12:12, 67.06it/s][20:07:36] UFFTYPER: Warning: hybridization set to SP3 for atom 35
#   0% 186/49282 [00:02<12:08, 67.39it/s][20:07:37] UFFTYPER: Unrecognized hybridization for atom: 0
# [20:07:37] UFFTYPER: Unrecognized atom type: Ru (0)
#   0% 238/49282 [00:03<12:29, 65.41it/s][20:07:37] WARNING: not removing hydrogen atom with neighbor that has non-tetrahedral stereochemistry
# [20:07:37] UFFTYPER: Unrecognized charge state for atom: 65
#   1% 362/49282 [00:05<11:40, 69.80it/s][20:07:39] UFFTYPER: Unrecognized atom type: Be+2 (0)
#   1% 586/49282 [00:09<13:10, 61.61it/s][20:07:43] UFFTYPER: Unrecognized atom type: Pt6+2 (0)
# [20:07:43] UFFTYPER: Unrecognized atom type: N_5 (1)
# [20:07:43] UFFTYPER: Unrecognized atom type: N_5 (2)
# [20:07:43] UFFTYPER: Unrecognized atom type: Pt6+2 (15)
# [20:07:43] UFFTYPER: Unrecognized atom type: N_5 (16)
# [20:07:43] UFFTYPER: Unrecognized atom type: N_5 (17)
#   1% 602/49282 [00:09<13:05, 61.95it/s][20:07:44] UFFTYPER: Unrecognized atom type: Se2+2 (0)
# [20:07:44] UFFTYPER: Unrecognized atom type: Se2+2 (1)
# [20:07:44] UFFTYPER: Unrecognized atom type: Se2+2 (2)
#   1% 618/49282 [00:09<13:01, 62.29it/s][20:07:44] UFFTYPER: Unrecognized atom type: Ru6 (60)
# [20:07:44] UFFTYPER: Unrecognized hybridization for atom: 0
# [20:07:44] UFFTYPER: Unrecognized atom type: Ag+1 (0)
# [20:07:44] UFFTYPER: Unrecognized atom type: Fe5+2 (1)
# [20:07:44] UFFTYPER: Unrecognized atom type: Fe5+2 (2)
# [20:07:44] UFFTYPER: Unrecognized atom type: Fe5+2 (3)
# [20:07:44] UFFTYPER: Unrecognized charge state for atom: 4
# [20:07:44] UFFTYPER: Unrecognized charge state for atom: 5
# [20:07:44] UFFTYPER: Unrecognized charge state for atom: 6
# [20:07:44] UFFTYPER: Unrecognized charge state for atom: 7
#   2% 762/49282 [00:12<12:54, 62.64it/s][20:07:46] UFFTYPER: Unrecognized hybridization for atom: 1
# [20:07:46] UFFTYPER: Unrecognized atom type: Rh (1)
#   2% 906/49282 [00:15<13:21, 60.35it/s][20:07:49] UFFTYPER: Unrecognized atom type: Cu4+1 (20)
#   2% 938/49282 [00:15<13:18, 60.58it/s][20:07:49] UFFTYPER: Unrecognized atom type: S_5+6 (4)
# [20:07:49] UFFTYPER: Unrecognized atom type: S_5+6 (20)
#   2% 1178/49282 [00:20<13:40, 58.66it/s][20:07:54] UFFTYPER: Unrecognized charge state for atom: 0
# [20:07:54] UFFTYPER: Unrecognized charge state for atom: 0
#   2% 1194/49282 [00:20<13:39, 58.71it/s][20:07:54] UFFTYPER: Unrecognized atom type: Ru6 (35)
#   3% 1418/49282 [00:23<13:05, 60.94it/s][20:07:57] UFFTYPER: Unrecognized atom type: N_5 (4)
# [20:07:57] UFFTYPER: Unrecognized atom type: Fe5+2 (21)
#   3% 1562/49282 [00:25<12:52, 61.77it/s][20:07:59] UFFTYPER: Unrecognized atom type: Fe5+2 (1)
# [20:07:59] UFFTYPER: Unrecognized atom type: Fe5+2 (2)
# [20:07:59] UFFTYPER: Unrecognized atom type: Fe5+2 (3)
# [20:07:59] UFFTYPER: Unrecognized atom type: Fe5+2 (4)
# [20:07:59] UFFTYPER: Unrecognized atom type: Fe5+2 (5)
# [20:07:59] UFFTYPER: Unrecognized atom type: Fe5+2 (6)
# [20:07:59] UFFTYPER: Unrecognized atom type: Fe5+2 (7)
# [20:07:59] UFFTYPER: Unrecognized atom type: Fe5+2 (8)
# [20:07:59] UFFTYPER: Unrecognized charge state for atom: 9
# [20:07:59] UFFTYPER: Unrecognized charge state for atom: 10
# [20:07:59] UFFTYPER: Unrecognized charge state for atom: 11
# [20:07:59] UFFTYPER: Unrecognized charge state for atom: 12
# [20:07:59] UFFTYPER: Unrecognized charge state for atom: 13
# [20:07:59] UFFTYPER: Unrecognized charge state for atom: 14
#   3% 1578/49282 [00:25<12:49, 61.97it/s][20:07:59] UFFTYPER: Unrecognized atom type: Cu5+1 (0)
# [20:07:59] UFFTYPER: Unrecognized atom type: O_5 (1)
#   4% 1834/49282 [00:29<12:51, 61.51it/s][20:08:04] UFFTYPER: Unrecognized charge state for atom: 10
#   4% 1914/49282 [00:31<12:50, 61.49it/s][20:08:05] UFFTYPER: Unrecognized hybridization for atom: 9
# [20:08:05] UFFTYPER: Unrecognized atom type: Os (9)
#   4% 2026/49282 [00:33<12:50, 61.33it/s][20:08:07] UFFTYPER: Unrecognized atom type: Pt5+2 (0)
# [20:08:07] UFFTYPER: Unrecognized atom type: N_5 (1)
# [20:08:07] UFFTYPER: Unrecognized atom type: N_5 (2)
#   4% 2090/49282 [00:34<12:49, 61.37it/s][20:08:08] UFFTYPER: Unrecognized atom type: V_5+5 (9)
#   6% 2900/49282 [00:44<11:56, 64.70it/s][20:08:19] UFFTYPER: Unrecognized atom type: Ru6 (78)
# [20:08:19] UFFTYPER: Unrecognized atom type: Ru6 (79)
#   6% 2944/49282 [00:45<11:53, 64.93it/s][20:08:19] UFFTYPER: Unrecognized charge state for atom: 14
# [20:08:19] UFFTYPER: Unrecognized atom type: Zn4+2 (14)
#   6% 3032/49282 [00:46<11:55, 64.67it/s][20:08:21] UFFTYPER: Unrecognized atom type: Ru6 (22)
#   6% 3142/49282 [00:48<11:52, 64.75it/s][20:08:22] UFFTYPER: Unrecognized atom type: Mo2+6 (0)
#   6% 3186/49282 [00:49<11:52, 64.66it/s][20:08:23] UFFTYPER: Unrecognized atom type: O_5 (1)
# [20:08:23] UFFTYPER: Unrecognized atom type: O_5 (2)
#   7% 3252/49282 [00:50<11:51, 64.67it/s][20:08:24] UFFTYPER: Unrecognized atom type: N_5 (25)
# [20:08:24] UFFTYPER: Unrecognized atom type: N_5 (27)
#   7% 3362/49282 [00:52<11:57, 63.99it/s][20:08:26] UFFTYPER: Unrecognized atom type: Ir6 (0)
#   7% 3670/49282 [00:58<12:02, 63.12it/s][20:08:32] UFFTYPER: Unrecognized atom type: Se2+2 (6)
#   8% 3758/49282 [00:59<11:59, 63.23it/s][20:08:33] UFFTYPER: Unrecognized atom type: S_5+4 (9)
#   8% 3780/49282 [00:59<12:00, 63.16it/s][20:08:34] UFFTYPER: Unrecognized atom type: Fe5+2 (0)
# [20:08:34] UFFTYPER: Unrecognized atom type: Fe5+2 (1)
# [20:08:34] UFFTYPER: Unrecognized atom type: Fe5+2 (2)
# [20:08:34] UFFTYPER: Unrecognized atom type: Fe5+2 (3)
# [20:08:34] UFFTYPER: Unrecognized charge state for atom: 4
# [20:08:34] UFFTYPER: Unrecognized charge state for atom: 5
# [20:08:34] UFFTYPER: Unrecognized charge state for atom: 6
# [20:08:34] UFFTYPER: Unrecognized charge state for atom: 7
# [20:08:34] UFFTYPER: Unrecognized atom type: Cu4+1 (0)
#   8% 4022/49282 [01:03<11:57, 63.04it/s][20:08:38] UFFTYPER: Unrecognized charge state for atom: 8
#   9% 4396/49282 [01:10<12:03, 62.03it/s][20:08:45] UFFTYPER: Unrecognized atom type: Ni3+2 (0)
#   9% 4440/49282 [01:11<12:01, 62.14it/s][20:08:45] UFFTYPER: Unrecognized atom type: O_5 (1)
# [20:08:45] UFFTYPER: Unrecognized atom type: O_5 (2)
#   9% 4484/49282 [01:12<12:01, 62.05it/s][20:08:46] UFFTYPER: Unrecognized charge state for atom: 5
#   9% 4594/49282 [01:14<11:59, 62.07it/s][20:08:48] UFFTYPER: Unrecognized charge state for atom: 12
# [20:08:48] UFFTYPER: Unrecognized charge state for atom: 15
# [20:08:48] UFFTYPER: Unrecognized charge state for atom: 16
# [20:08:48] UFFTYPER: Unrecognized atom type: Ru6 (36)
#  10% 4704/49282 [01:15<11:58, 62.05it/s][20:08:50] UFFTYPER: Unrecognized atom type: Ru6 (14)
#  11% 5188/49282 [01:24<11:59, 61.31it/s][20:08:58] UFFTYPER: Unrecognized hybridization for atom: 10
# [20:08:58] UFFTYPER: Unrecognized atom type: Ru (10)
#  11% 5474/49282 [01:29<11:56, 61.13it/s][20:09:04] UFFTYPER: Unrecognized hybridization for atom: 1
# [20:09:04] UFFTYPER: Unrecognized atom type: Ir (1)
# [20:09:04] UFFTYPER: Unrecognized atom type: N_5 (14)
# [20:09:04] UFFTYPER: Unrecognized atom type: N_5 (17)
# [20:09:04] UFFTYPER: Unrecognized atom type: C_5 (30)
# [20:09:04] UFFTYPER: Unrecognized atom type: C_5 (31)
# [20:09:04] UFFTYPER: Unrecognized atom type: C_5 (32)
#  11% 5562/49282 [01:30<11:53, 61.30it/s][20:09:05] UFFTYPER: Warning: hybridization set to SP3 for atom 39
#  11% 5584/49282 [01:31<11:52, 61.31it/s][20:09:05] WARNING: not removing hydrogen atom with neighbor that has non-tetrahedral stereochemistry
#  11% 5628/49282 [01:32<11:53, 61.17it/s][20:09:06] UFFTYPER: Unrecognized atom type: Mo+6 (0)
#  11% 5650/49282 [01:32<11:52, 61.20it/s][20:09:06] UFFTYPER: Unrecognized charge state for atom: 4
#  12% 5738/49282 [01:33<11:50, 61.30it/s][20:09:07] UFFTYPER: Unrecognized atom type: Pu+4 (0)
#  12% 5826/49282 [01:35<11:52, 60.99it/s][20:09:09] UFFTYPER: Unrecognized charge state for atom: 0
# [20:09:09] UFFTYPER: Unrecognized charge state for atom: 2
#  12% 5980/49282 [01:38<11:50, 60.93it/s][20:09:12] UFFTYPER: Unrecognized charge state for atom: 2
# [20:09:12] UFFTYPER: Unrecognized charge state for atom: 4
#  12% 6002/49282 [01:38<11:49, 61.03it/s][20:09:12] UFFTYPER: Unrecognized atom type: S_5+4 (11)
#  12% 6134/49282 [01:39<11:42, 61.44it/s][20:09:14] UFFTYPER: Unrecognized atom type: Au6+3 (15)
#  12% 6156/49282 [01:40<11:41, 61.51it/s][20:09:14] UFFTYPER: Unrecognized atom type: Fe4+2 (21)
#  13% 6222/49282 [01:41<11:42, 61.30it/s][20:09:15] UFFTYPER: Unrecognized atom type: Ca3+2 (0)
# [20:09:15] UFFTYPER: Unrecognized atom type: O_5 (1)
# [20:09:15] UFFTYPER: Unrecognized atom type: O_5 (2)
# [20:09:15] UFFTYPER: Unrecognized atom type: O_5 (3)
# [20:09:15] UFFTYPER: Unrecognized atom type: O_5 (4)
# [20:09:15] UFFTYPER: Unrecognized atom type: O_5 (5)
# [20:09:15] UFFTYPER: Unrecognized atom type: O_5 (6)
# [20:09:15] UFFTYPER: Unrecognized atom type: O_5 (9)
#  14% 6728/49282 [01:49<11:34, 61.24it/s][20:09:24] UFFTYPER: Unrecognized atom type: Ir3 (0)
# [20:09:24] UFFTYPER: Unrecognized atom type: N_5 (13)
# [20:09:24] UFFTYPER: Unrecognized atom type: N_5 (16)
#  16% 7696/49282 [02:10<11:45, 58.92it/s][20:09:44] UFFTYPER: Unrecognized charge state for atom: 3
#  16% 7718/49282 [02:11<11:45, 58.90it/s][20:09:45] UFFTYPER: Unrecognized hybridization for atom: 1
# [20:09:45] UFFTYPER: Unrecognized atom type: Pt+2 (1)
#  16% 7872/49282 [02:14<11:49, 58.36it/s][20:09:49] UFFTYPER: Warning: hybridization set to SP3 for atom 0
#  16% 7894/49282 [02:15<11:49, 58.31it/s][20:09:49] WARNING: not removing hydrogen atom with neighbor that has non-tetrahedral stereochemistry
#  16% 7938/49282 [02:16<11:49, 58.25it/s][20:09:50] UFFTYPER: Unrecognized atom type: Fe4+2 (0)
#  16% 8048/49282 [02:18<11:50, 58.00it/s][20:09:53] UFFTYPER: Unrecognized atom type: Co4+3 (40)
#  17% 8466/49282 [02:30<12:07, 56.11it/s][20:10:05] UFFTYPER: Unrecognized atom type: Fe5+2 (14)
#  19% 9148/49282 [02:48<12:18, 54.35it/s][20:10:22] UFFTYPER: Unrecognized hybridization for atom: 3
# [20:10:22] UFFTYPER: Unrecognized atom type: Ru (3)
#  19% 9192/49282 [02:48<12:16, 54.40it/s][20:10:23] UFFTYPER: Unrecognized atom type: Fe4+2 (0)
#  19% 9390/49282 [02:52<12:14, 54.33it/s][20:10:27] UFFTYPER: Unrecognized hybridization for atom: 29
# [20:10:27] UFFTYPER: Unrecognized charge state for atom: 29
# [20:10:27] UFFTYPER: Unrecognized atom type: Tb+3 (29)
#  19% 9434/49282 [02:53<12:13, 54.36it/s][20:10:28] UFFTYPER: Unrecognized atom type: Fe4+2 (48)
#  19% 9478/49282 [02:54<12:14, 54.22it/s][20:10:29] UFFTYPER: Unrecognized charge state for atom: 6
# [20:10:29] UFFTYPER: Unrecognized atom type: Pr3+3 (6)
#  20% 9918/49282 [03:03<12:10, 53.90it/s][20:10:39] UFFTYPER: Unrecognized atom type: Ni6+2 (2)
# [20:10:39] UFFTYPER: Unrecognized charge state for atom: 3
# [20:10:39] UFFTYPER: Unrecognized charge state for atom: 5
# [20:10:39] UFFTYPER: Unrecognized hybridization for atom: 7
# [20:10:39] UFFTYPER: Unrecognized atom type: Fe+2 (7)
# [20:10:39] UFFTYPER: Unrecognized charge state for atom: 8
#  20% 9984/49282 [03:06<12:13, 53.59it/s][20:10:41] UFFTYPER: Unrecognized hybridization for atom: 1
# [20:10:41] UFFTYPER: Unrecognized atom type: Fe+2 (1)
#  21% 10116/49282 [03:11<12:20, 52.91it/s][20:10:45] UFFTYPER: Unrecognized atom type: Se2+2 (22)
#  21% 10160/49282 [03:11<12:19, 52.92it/s][20:10:46] UFFTYPER: Unrecognized atom type: S_5+4 (33)
#  21% 10182/49282 [03:12<12:18, 52.92it/s][20:10:46] UFFTYPER: Unrecognized atom type: Fe4+2 (45)
#  22% 10732/49282 [03:24<12:14, 52.51it/s][20:10:58] UFFTYPER: Warning: hybridization set to SP3 for atom 32
#  22% 10776/49282 [03:25<12:14, 52.43it/s][20:11:00] UFFTYPER: Unrecognized atom type: Se2+2 (29)
#  22% 10952/49282 [03:29<12:14, 52.16it/s][20:11:04] UFFTYPER: Unrecognized hybridization for atom: 3
# [20:11:04] UFFTYPER: Unrecognized atom type: Os (3)
#  22% 11062/49282 [03:32<12:12, 52.15it/s][20:11:06] UFFTYPER: Unrecognized atom type: Cu4+1 (15)
#  25% 12118/49282 [03:52<11:51, 52.20it/s][20:11:26] UFFTYPER: Unrecognized atom type: Mo5+6 (0)
# [20:11:26] UFFTYPER: Unrecognized atom type: Mo5+6 (1)
# [20:11:26] WARNING: not removing hydrogen atom with neighbor that has non-tetrahedral stereochemistry
# [20:11:26] WARNING: not removing hydrogen atom with neighbor that has non-tetrahedral stereochemistry
# [20:11:26] WARNING: not removing hydrogen atom with neighbor that has non-tetrahedral stereochemistry
# [20:11:26] WARNING: not removing hydrogen atom with neighbor that has non-tetrahedral stereochemistry
#  26% 12690/49282 [04:03<11:42, 52.10it/s][20:11:38] UFFTYPER: Warning: hybridization set to SP3 for atom 63
#  33% 16276/49282 [05:23<10:56, 50.30it/s][20:12:57] UFFTYPER: Unrecognized charge state for atom: 24
#  33% 16496/49282 [05:30<10:56, 49.97it/s][20:13:04] UFFTYPER: Unrecognized atom type: Ru6 (21)
# [20:13:04] UFFTYPER: Unrecognized atom type: O_5 (25)
#  34% 16584/49282 [05:32<10:55, 49.92it/s][20:13:06] UFFTYPER: Unrecognized charge state for atom: 7
# [20:13:06] UFFTYPER: Unrecognized atom type: As5+3 (7)
#  34% 16694/49282 [05:35<10:54, 49.82it/s][20:13:09] UFFTYPER: Unrecognized atom type: Ru2 (16)
#  34% 16760/49282 [05:37<10:54, 49.68it/s][20:13:12] UFFTYPER: Warning: hybridization set to SP3 for atom 61
# [20:13:12] UFFTYPER: Warning: hybridization set to SP3 for atom 62
# [20:13:12] UFFTYPER: Unrecognized atom type: W_6 (63)
# [20:13:12] UFFTYPER: Unrecognized atom type: W_6 (64)
# [20:13:12] UFFTYPER: Unrecognized atom type: W_6 (65)
# [20:13:12] UFFTYPER: Unrecognized atom type: W_6 (66)
# [20:13:12] UFFTYPER: Unrecognized atom type: W_6 (67)
# [20:13:12] UFFTYPER: Unrecognized atom type: W_6 (68)
# [20:13:12] UFFTYPER: Unrecognized atom type: W_6 (69)
# [20:13:12] UFFTYPER: Unrecognized atom type: W_6 (70)
# [20:13:12] UFFTYPER: Unrecognized atom type: W_6 (71)
# [20:13:12] UFFTYPER: Unrecognized atom type: W_6 (72)
# [20:13:12] UFFTYPER: Unrecognized atom type: W_6 (73)
# [20:13:12] UFFTYPER: Unrecognized atom type: W_6 (74)
# [20:13:12] UFFTYPER: Unrecognized atom type: W_6 (75)
# [20:13:12] UFFTYPER: Unrecognized atom type: W_6 (76)
# [20:13:12] UFFTYPER: Unrecognized atom type: W_6 (77)
# [20:13:12] UFFTYPER: Unrecognized atom type: W_6 (78)
# [20:13:12] UFFTYPER: Unrecognized atom type: W_6 (79)
# [20:13:12] UFFTYPER: Unrecognized atom type: Mn5+2 (80)
#  41% 20214/49282 [07:26<10:42, 45.28it/s][20:15:00] UFFTYPER: Unrecognized charge state for atom: 0
#  42% 20698/49282 [07:45<10:42, 44.47it/s][20:15:20] UFFTYPER: Unrecognized atom type: O_5 (1)
# [20:15:20] UFFTYPER: Unrecognized atom type: O_5 (2)
# [20:15:20] UFFTYPER: Unrecognized atom type: O_5 (3)
# [20:15:20] UFFTYPER: Unrecognized atom type: O_5 (4)
# [20:15:20] UFFTYPER: Unrecognized atom type: O_5 (5)
#  42% 20742/49282 [07:48<10:45, 44.24it/s][20:15:23] UFFTYPER: Warning: hybridization set to SP3 for atom 10
#  42% 20918/49282 [07:57<10:47, 43.82it/s][20:15:31] UFFTYPER: Unrecognized atom type: Cu5+1 (0)
#  43% 21116/49282 [08:11<10:56, 42.93it/s][20:15:46] UFFTYPER: Unrecognized charge state for atom: 4
#  43% 21138/49282 [08:14<10:58, 42.75it/s][20:15:51] UFFTYPER: Unrecognized charge state for atom: 15
# [20:15:51] UFFTYPER: Unrecognized hybridization for atom: 16
# [20:15:51] UFFTYPER: Unrecognized atom type: Ru (16)
#  46% 22502/49282 [09:11<10:56, 40.81it/s][20:16:45] UFFTYPER: Unrecognized atom type: Ru5 (13)
#  48% 23734/49282 [09:53<10:38, 40.00it/s][20:17:27] UFFTYPER: Unrecognized atom type: Ru6 (51)
#  49% 24086/49282 [10:03<10:31, 39.93it/s][20:17:37] UFFTYPER: Unrecognized atom type: Fe4+2 (38)
#  49% 24108/49282 [10:03<10:30, 39.93it/s][20:17:38] UFFTYPER: Unrecognized atom type: Fe2+2 (0)
#  50% 24658/49282 [10:14<10:14, 40.10it/s][20:17:49] UFFTYPER: Unrecognized atom type: Au6+3 (15)
#  51% 25208/49282 [10:29<10:00, 40.06it/s][20:18:03] UFFTYPER: Unrecognized charge state for atom: 0
# [20:18:03] UFFTYPER: Unrecognized atom type: Ga+3 (0)
#  53% 26110/49282 [10:54<09:40, 39.91it/s][20:18:28] Molecule does not have explicit Hs. Consider calling AddHs()
# [20:18:28] WARNING: not removing hydrogen atom without neighbors
#  55% 27078/49282 [11:35<09:30, 38.93it/s][20:19:10] UFFTYPER: Unrecognized hybridization for atom: 4
# [20:19:10] UFFTYPER: Unrecognized atom type: Ru (4)
# [20:19:10] UFFTYPER: Unrecognized atom type: N_5 (9)
# [20:19:10] UFFTYPER: Unrecognized atom type: N_5 (12)
#  56% 27760/49282 [12:06<09:23, 38.19it/s][20:19:41] UFFTYPER: Unrecognized atom type: Ca1+2 (13)
# [20:19:41] UFFTYPER: Unrecognized charge state for atom: 0
# [20:19:41] UFFTYPER: Unrecognized atom type: Fe5+2 (1)
# [20:19:41] UFFTYPER: Unrecognized charge state for atom: 3
# [20:19:41] UFFTYPER: Unrecognized charge state for atom: 4
# [20:19:41] UFFTYPER: Unrecognized hybridization for atom: 6
# [20:19:41] UFFTYPER: Unrecognized atom type: C_ (6)
# [20:19:41] UFFTYPER: Unrecognized charge state for atom: 11
# [20:19:41] UFFTYPER: Unrecognized charge state for atom: 13
# [20:19:41] UFFTYPER: Unrecognized charge state for atom: 16
#  57% 28288/49282 [12:20<09:09, 38.19it/s][20:19:55] UFFTYPER: Unrecognized atom type: Ir6 (0)
# [20:19:55] UFFTYPER: Unrecognized atom type: N_5 (1)
# [20:19:55] UFFTYPER: Unrecognized atom type: N_5 (2)
# [20:19:55] UFFTYPER: Unrecognized atom type: N_5 (3)
# [20:19:55] UFFTYPER: Unrecognized atom type: N_5 (4)
# [20:19:55] UFFTYPER: Unrecognized atom type: N_5 (5)
# [20:19:55] UFFTYPER: Unrecognized atom type: N_5 (6)
#  58% 28596/49282 [12:29<09:01, 38.18it/s][20:20:03] UFFTYPER: Unrecognized hybridization for atom: 17
# [20:20:03] UFFTYPER: Unrecognized atom type: Ir (17)
#  59% 29190/49282 [12:51<08:51, 37.81it/s][20:20:26] UFFTYPER: Unrecognized atom type: Cu4+1 (12)
#  64% 31368/49282 [14:10<08:05, 36.87it/s][20:21:46] UFFTYPER: Unrecognized charge state for atom: 0
# [20:21:46] UFFTYPER: Unrecognized atom type: La+3 (0)
#  65% 31830/49282 [14:29<07:56, 36.62it/s][20:22:04] UFFTYPER: Unrecognized hybridization for atom: 20
# [20:22:04] UFFTYPER: Unrecognized atom type: Pt+2 (20)
#  67% 32842/49282 [15:15<07:38, 35.87it/s][20:22:49] UFFTYPER: Warning: hybridization set to SP3 for atom 0
# [20:22:49] UFFTYPER: Unrecognized charge state for atom: 0
#  67% 32864/49282 [15:16<07:37, 35.86it/s][20:22:51] UFFTYPER: Unrecognized atom type: Mn2+2 (0)
# [20:22:51] UFFTYPER: Unrecognized atom type: Mn1+2 (0)
#  67% 32886/49282 [15:17<07:37, 35.86it/s][20:22:51] UFFTYPER: Unrecognized atom type: Fe4+2 (0)
#  68% 33304/49282 [15:34<07:28, 35.62it/s][20:23:10] UFFTYPER: Warning: hybridization set to SP3 for atom 0
#  69% 33788/49282 [15:56<07:18, 35.33it/s][20:23:30] UFFTYPER: Unrecognized atom type: Fe4+2 (0)
#  72% 35614/49282 [17:05<06:33, 34.74it/s]

# %% [markdown]
# # 2. [Optional] Inference and MSA tests

# %% [markdown]
# ## 2.a This first converts a PDB into a Protenix-compatible JSON

# %%
# !protenix tojson --input /content/drive/MyDrive/colab_cache/afmfold-data/4G1E.pdb --out_dir /content/drive/MyDrive/colab_cache/afmfold-data/
# Out:
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-01-29 22:07:39,627 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:467] INFO runner.batch_inference: run tojson with input=/content/drive/MyDrive/colab_cache/afmfold-data/4G1E.pdb, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/, altloc=first, assembly_id=None
# 2026-01-29 22:07:39,628 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:487] INFO runner.batch_inference: will tojson jsons for 1 input files with `pdb` or `cif` format.
# 2026-01-29 22:07:46,513 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:517] INFO runner.batch_inference: 1 generated jsons have been saved to /content/drive/MyDrive/colab_cache/afmfold-data/.

# %% [markdown]
# ## 2.b Then, lookup MSA history

# %%
# !protenix msa --input /content/drive/MyDrive/colab_cache/afmfold-data/4G1E-without-msa.json --out_dir /content/drive/MyDrive/colab_cache/afmfold-data/
# Out:
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2025-12-27 05:06:17,053 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:539] INFO runner.batch_inference: run msa with input=/content/drive/MyDrive/colab_cache/afmfold-data/4G1E-without-msa.json, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/
# 2025-12-27 05:06:17,683 [/usr/local/lib/python3.12/dist-packages/runner/msa_search.py:98] INFO runner.msa_search: starting to update msa result for seq 0 in /content/drive/MyDrive/colab_cache/afmfold-data/4G1E-without-msa.json
# 2025-12-27 05:06:18,110 [/usr/local/lib/python3.12/dist-packages/protenix/web_service/colab_request_utils.py:209] INFO protenix.web_service.colab_request_utils: Msa server is running.
# 2025-12-27 05:06:24,261 [/usr/local/lib/python3.12/dist-packages/runner/msa_search.py:113] INFO runner.msa_search: update msa result success and save to /content/drive/MyDrive/colab_cache/afmfold-data/4G1E-without-msa-add-msa.json
# 2025-12-27 05:06:24,262 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:544] INFO runner.batch_inference: msa results have been update to /content/drive/MyDrive/colab_cache/afmfold-data/4G1E-without-msa-add-msa.json

# %% [markdown]
# ## 2.c Run "standard" inference

# %%
# !protenix predict --input /content/drive/MyDrive/colab_cache/afmfold-data/4G1E-add-msa.json --out_dir  /content/drive/MyDrive/colab_cache/afmfold-data/ --seeds 101 --model_name "protenix_base_default_v0.5.0"
# Out:
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2025-12-27 05:05:18,747 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:383] INFO runner.batch_inference: run infer with input=/content/drive/MyDrive/colab_cache/afmfold-data/4G1E-add-msa.json, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/, sample=5
# 2025-12-27 05:05:18,747 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:408] INFO runner.batch_inference: Using the default params for inference for model protenix_base_default_v0.5.0: cycle=10, step=200, use_msa=True
# 2025-12-27 05:05:18,748 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:258] INFO runner.batch_inference: will infer with 1 jsons
# 2025-12-27 05:05:18,809 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:209] INFO runner.batch_inference: Inference by Protenix: model_size: base, with_feature: default, model_version: v0.5.0, dtype: bf16
# 2025-12-27 05:05:18,810 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:212] INFO runner.batch_inference: Triangle_multiplicative kernel: cuequivariance, Triangle_attention kernel: triattention
# 2025-12-27 05:05:18,810 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:215] INFO runner.batch_inference: enable_diffusion_shared_vars_cache: True, enable_efficient_fusion: True, enable_tf32: True
# 2025-12-27 05:05:18,810 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:231] INFO runner.inference: Downloading data cache from
#  https://af3-dev.tos-cn-beijing.volces.com/release_data/components.v20240608.cif... to /usr/local/lib/python3.12/dist-packages/release_data/ccd_cache/components.v20240608.cif
# [------------------------------] 0.0%
# Aborted!
# ^C

# %% [markdown]
# # 3. Using AFMFold, attempt to generate candidate conformers using AFMFold built-in methods

# %% [markdown]
# ## 3.a Generate candidate conformers
#
# Prefer to use PACE to do this. It takes a very long time. Around 2 hours per candidate.
#
# The one error I got stuck on is figuring out that the Protenix component files were incompletely downloaded or corrupted. In which case, delete release_data (or just the *.pkl files) and download again.

# %%
# !python /content/drive/MyDrive/colab_cache/afmfold/scripts/generate_candidates.py --native-pdb /content/drive/MyDrive/colab_cache/afmfold/storage/4G1E.pdb --name 4G1E --json-file /content/drive/MyDrive/colab_cache/afmfold-data/4G1E-add-msa.json --out-dir /content/drive/MyDrive/colab_cache/afmfold-data/candidates

# %% [markdown]
# ## 3.b [Failed] Test whether we can get the EC and EO conformations from BC PDB inputs (4G1E) via Protenix.
#
# 4G1E is a solved crystal structure of integrin alpha V beta 3 in the bent-closed (BC) conformation [[PDB]](https://www.rcsb.org/structure/4G1E)

# %%
import os
import itertools
import numpy as np
import mdtraj as md
import afmfold.domain as domain
from afmfold.domain import compute_domain_distance
from afmfold.runner.batch_inference import inference_jsons

json_file = "/content/drive/MyDrive/colab_cache/afmfold-data/4G1E-add-msa.json"
out_dir = "/content/drive/MyDrive/colab_cache/afmfold-data/test_guided"
name = "4G1E"
bc_pdb = "/content/drive/MyDrive/colab_cache/afmfold/storage/4G1E.pdb"

# Use intra-chain domain pairs so we steer bend/extension, not alpha-beta separation.
domain_pairs = [
    (domain.INTEGRIN_DOMAINS["alpha_head_thigh"], domain.INTEGRIN_DOMAINS["alpha_calf"]),
    (domain.INTEGRIN_DOMAINS["alpha_calf"], domain.INTEGRIN_DOMAINS["alpha_coil"]),
    (domain.INTEGRIN_DOMAINS["beta_head_hybrid_egf1"], domain.INTEGRIN_DOMAINS["beta_tail_egf2_3_4_btail"]),
    (domain.INTEGRIN_DOMAINS["beta_tail_egf2_3_4_btail"], domain.INTEGRIN_DOMAINS["beta_coil"]),
]

def target_from_pdb(pdb_path):
    traj = md.load(pdb_path)
    dists = []
    for d1, d2 in domain_pairs:
        d = compute_domain_distance(traj, d1, d2)
        dists.append(d.item() * 10.0)  # nm -> Å
    return np.array(dists)

bc_dist = target_from_pdb(bc_pdb)

# Offsets in Angstroms; tune these to bias toward EO/EC.
eo_offsets = [20.0, 30.0, 40.0]
ec_offsets = [-5.0, -10.0]
y_max_list = [0.6, 1.0, 2.0]
t_start_list = [0.1, 0.2, 0.4]
seeds = [101, 102, 103, 104]
n_sample = 2

def run_target(target, seed, y_max, t_start):
    kwargs = {
        "sample_diffusion.N_sample": n_sample,
        "guidance_kwargs.t_start": t_start,
        "guidance_kwargs.manual": target,
        "guidance_kwargs.scaling_kwargs.func_type": "constant",
        "guidance_kwargs.scaling_kwargs.y_max": y_max,
        "guidance_kwargs.domain_pairs": domain_pairs,
    }
    inference_jsons(json_file, out_dir, seeds=(seed,), **kwargs)

jobs = []
for eo_offset, y_max, t_start, seed in itertools.product(eo_offsets, y_max_list, t_start_list, seeds):
    jobs.append(("EO", bc_dist + eo_offset, seed, y_max, t_start))
for ec_offset, y_max, t_start, seed in itertools.product(ec_offsets, y_max_list, t_start_list, seeds):
    jobs.append(("EC", bc_dist + ec_offset, seed, y_max, t_start))

shard_id = int(os.environ.get("SHARD_ID", "0"))
num_shards = int(os.environ.get("NUM_SHARDS", "1"))

os.makedirs(out_dir, exist_ok=True)

for idx, (label, target, seed, y_max, t_start) in enumerate(jobs):
    if idx % num_shards != shard_id:
        continue
    print(f"[{idx + 1}/{len(jobs)}][{label}] seed={seed} y_max={y_max} t_start={t_start} target={target}")
    run_target(target, seed, y_max=y_max, t_start=t_start)
# Out:
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:56: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-01-04 06:53:00,152 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/runner/batch_inference.py:213] INFO afmfold.runner.batch_inference: will infer with 1 jsons
# 2026-01-04 06:53:00,627 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/runner/inference.py:167] INFO afmfold.runner.inference: Distributed environment: world size: 1, global rank: 0, local rank: 0
# 2026-01-04 06:53:00,647 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/runner/inference.py:75] INFO root: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0] - DEVICE: cuda:0
# 2026-01-04 06:53:00,663 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/runner/inference.py:99] INFO root: Finished init ENV.
# train scheduler 16.0
# inference scheduler 16.0
# Diffusion Module has 16.0
# 2026-01-04 06:53:06,066 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/runner/inference.py:167] INFO afmfold.runner.inference: Loading from /content/drive/My Drive/colab_cache/afmfold/src/afmfold/./release_data/checkpoint/model_v0.2.0.pt, strict: True
# 2026-01-04 06:53:43,799 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/runner/inference.py:167] INFO afmfold.runner.inference: Sampled key: module.input_embedder.atom_attention_encoder.linear_no_bias_f.weight
# 2026-01-04 06:53:43,972 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/runner/inference.py:167] INFO afmfold.runner.inference: Finish loading checkpoint.
#   0%|          | 0/1 [00:00<?, ?it/s]2026-01-04 06:53:44,598 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/runner/msa_search.py:126] INFO afmfold.runner.msa_search: do not need to update msa result, so return itself /content/drive/MyDrive/colab_cache/afmfold-data/4G1E-add-msa.json
# 2026-01-04 06:53:44,599 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/runner/inference.py:226] INFO afmfold.runner.inference: Loading data from
# /content/drive/MyDrive/colab_cache/afmfold-data/4G1E-add-msa.json
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# 2026-01-04 06:53:46,815 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/protenix/data/infer_data_pipeline.py:216] INFO afmfold.protenix.data.infer_data_pipeline: Featurizing 4G1E...
# 2026-01-04 06:54:53,447 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/runner/inference.py:252] INFO afmfold.runner.inference: [Rank 0 (1/1)] 4G1E: N_asym 71, N_token 2340, N_atom 13635, N_msa 10561
# 2026-01-04 07:24:21,383 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/protenix/data/utils.py:426] INFO afmfold.protenix.data.utils: Saved cif in /content/drive/MyDrive/colab_cache/afmfold-data/test_guided/4G1E/seed_101/predictions/4G1E_seed_101_sample_0.cif
# 2026-01-04 07:24:21,407 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/runner/inference.py:271] INFO afmfold.runner.inference: [Rank 0] 4G1E succeeded.
# Results saved to /content/drive/MyDrive/colab_cache/afmfold-data/test_guided
# 100%|██████████| 1/1 [30:37<00:00, 1837.73s/it]
# 2026-01-04 07:24:21,735 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/runner/batch_inference.py:213] INFO afmfold.runner.batch_inference: will infer with 1 jsons
# 2026-01-04 07:24:21,746 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/runner/inference.py:167] INFO afmfold.runner.inference: Distributed environment: world size: 1, global rank: 0, local rank: 0
# 2026-01-04 07:24:21,746 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/runner/inference.py:75] INFO root: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0] - DEVICE: cuda:0
# 2026-01-04 07:24:21,747 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/runner/inference.py:99] INFO root: Finished init ENV.
# train scheduler 16.0
# inference scheduler 16.0
# Diffusion Module has 16.0
# 2026-01-04 07:24:27,057 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/runner/inference.py:167] INFO afmfold.runner.inference: Loading from /content/drive/My Drive/colab_cache/afmfold/src/afmfold/./release_data/checkpoint/model_v0.2.0.pt, strict: True
# 2026-01-04 07:24:29,717 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/runner/inference.py:167] INFO afmfold.runner.inference: Sampled key: module.input_embedder.atom_attention_encoder.linear_no_bias_f.weight
# 2026-01-04 07:24:29,895 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/runner/inference.py:167] INFO afmfold.runner.inference: Finish loading checkpoint.
#   0%|          | 0/1 [00:00<?, ?it/s]2026-01-04 07:24:29,912 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/runner/msa_search.py:126] INFO afmfold.runner.msa_search: do not need to update msa result, so return itself /content/drive/MyDrive/colab_cache/afmfold-data/4G1E-add-msa.json
# 2026-01-04 07:24:29,913 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/runner/inference.py:226] INFO afmfold.runner.inference: Loading data from
# /content/drive/MyDrive/colab_cache/afmfold-data/4G1E-add-msa.json
# 2026-01-04 07:24:30,591 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/protenix/data/infer_data_pipeline.py:216] INFO afmfold.protenix.data.infer_data_pipeline: Featurizing 4G1E...
# 2026-01-04 07:25:17,244 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/runner/inference.py:252] INFO afmfold.runner.inference: [Rank 0 (1/1)] 4G1E: N_asym 71, N_token 2340, N_atom 13635, N_msa 10561
# 2026-01-04 07:54:43,508 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/protenix/data/utils.py:426] INFO afmfold.protenix.data.utils: Saved cif in /content/drive/MyDrive/colab_cache/afmfold-data/test_guided/4G1E/seed_102/predictions/4G1E_seed_102_sample_0.cif
# 2026-01-04 07:54:43,533 [/content/drive/My Drive/colab_cache/afmfold/src/afmfold/runner/inference.py:271] INFO afmfold.runner.inference: [Rank 0] 4G1E succeeded.
# Results saved to /content/drive/MyDrive/colab_cache/afmfold-data/test_guided
# 100%|██████████| 1/1 [30:13<00:00, 1813.96s/it]

# %% [markdown]
# # 4. Try RoyalMD instead with a pulling force added to attempt to generate largely different conformations.
#
# Now we want to see if we can use Protenix to relax the structure a bit further.

# %% [markdown]
# ## 4.a This first converts a PDB into a Protenix-compatible JSON

# %%
import os

pdb_dir = '/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/'
output_dir = pdb_dir # Save output JSONs in the same directory

pdb_files = [f for f in os.listdir(pdb_dir) if f.endswith('.pdb')]

print(f"Found {len(pdb_files)} PDB files in {pdb_dir}:")
for pdb_file in pdb_files:
    print(pdb_file)
# Out:
# Found 7 PDB files in /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/:
# production_trajectory_frame_00.pdb
# production_trajectory_frame_05.pdb
# production_trajectory_frame_10.pdb
# production_trajectory_frame_15.pdb
# production_trajectory_frame_20.pdb
# production_trajectory_frame_25.pdb
# production_trajectory_frame_30.pdb

# %%
import os
import glob # Import glob to find files easily

pdb_dir = '/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/'
output_dir = pdb_dir # Save output JSONs in the same directory

pdb_files = [f for f in os.listdir(pdb_dir) if f.endswith('.pdb')]

for pdb_file in pdb_files:
    input_path = os.path.join(pdb_dir, pdb_file)
    print(f"Processing: {input_path}")

    # Extract the suffix ID (e.g., '00', '05') from the PDB filename
    # Assuming filename is like 'production_trajectory_frame_XX.pdb'
    parts = pdb_file.split('_')
    suffix_id = None
    if len(parts) >= 4 and parts[2] == 'frame':
        suffix_id = parts[3].split('.')[0] # Get 'XX' from 'XX.pdb'

    if suffix_id:
        desired_json_name = f"frame_{suffix_id}-without-msa.json"
    else:
        # Fallback if PDB name format is unexpected, use base name
        base_name = os.path.splitext(pdb_file)[0]
        desired_json_name = f"{base_name}-without-msa.json"

    target_json_path = os.path.join(output_dir, desired_json_name)

    # Check if the target JSON already exists to avoid re-running if not necessary
    if os.path.exists(target_json_path):
        print(f"Skipping {pdb_file}: {desired_json_name} already exists.")
        continue

    # Get list of JSON files before running the command
    json_files_before = set(glob.glob(os.path.join(output_dir, '*.json')))

    # Run the protenix tojson command
    # !protenix tojson --input "{input_path}" --out_dir "{output_dir}"

    # Get list of JSON files after running the command
    json_files_after = set(glob.glob(os.path.join(output_dir, '*.json')))

    # Find the newly generated JSON file
    new_json_files = list(json_files_after - json_files_before)

    if new_json_files:
        if len(new_json_files) == 1:
            generated_json_path = new_json_files[0]
            print(f"Found newly generated JSON: {generated_json_path}")
            print(f"Renaming to: {desired_json_name}")
            os.rename(generated_json_path, target_json_path)
            print(f"Successfully renamed {os.path.basename(generated_json_path)} to {desired_json_name}")
        else:
            print(f"Warning: Multiple new JSON files generated. Cannot determine which to rename for {pdb_file}.")
            for f in new_json_files:
                print(f" - {f}")
    else:
        print(f"Error: No new JSON file found after processing {pdb_file}.")
# Out:
# Processing: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/production_trajectory_frame_00.pdb
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-01-30 03:44:12,200 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:467] INFO runner.batch_inference: run tojson with input=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/production_trajectory_frame_00.pdb, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/, altloc=first, assembly_id=None
# 2026-01-30 03:44:12,201 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:487] INFO runner.batch_inference: will tojson jsons for 1 input files with `pdb` or `cif` format.
# 2026-01-30 03:44:19,786 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:517] INFO runner.batch_inference: 1 generated jsons have been saved to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/.
# Found newly generated JSON: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/production_trajector-78a38f349699441db97ab5f6de8dfa19.json
# Renaming to: frame_00-without-msa.json
# Successfully renamed production_trajector-78a38f349699441db97ab5f6de8dfa19.json to frame_00-without-msa.json
# Processing: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/production_trajectory_frame_05.pdb
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-01-30 03:44:24,550 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:467] INFO runner.batch_inference: run tojson with input=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/production_trajectory_frame_05.pdb, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/, altloc=first, assembly_id=None
# 2026-01-30 03:44:24,551 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:487] INFO runner.batch_inference: will tojson jsons for 1 input files with `pdb` or `cif` format.
# 2026-01-30 03:44:32,689 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:517] INFO runner.batch_inference: 1 generated jsons have been saved to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/.
# Found newly generated JSON: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/production_trajector-362a6c95f2c5425d99c0cf25982faa74.json
# Renaming to: frame_05-without-msa.json
# Successfully renamed production_trajector-362a6c95f2c5425d99c0cf25982faa74.json to frame_05-without-msa.json
# Processing: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/production_trajectory_frame_10.pdb
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-01-30 03:44:37,482 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:467] INFO runner.batch_inference: run tojson with input=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/production_trajectory_frame_10.pdb, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/, altloc=first, assembly_id=None
# 2026-01-30 03:44:37,483 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:487] INFO runner.batch_inference: will tojson jsons for 1 input files with `pdb` or `cif` format.
# 2026-01-30 03:44:45,516 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:517] INFO runner.batch_inference: 1 generated jsons have been saved to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/.
# Found newly generated JSON: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/production_trajector-f91c9a06092b41268d90f28893d2f45e.json
# Renaming to: frame_10-without-msa.json
# Successfully renamed production_trajector-f91c9a06092b41268d90f28893d2f45e.json to frame_10-without-msa.json
# Processing: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/production_trajectory_frame_15.pdb
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-01-30 03:44:50,198 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:467] INFO runner.batch_inference: run tojson with input=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/production_trajectory_frame_15.pdb, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/, altloc=first, assembly_id=None
# 2026-01-30 03:44:50,199 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:487] INFO runner.batch_inference: will tojson jsons for 1 input files with `pdb` or `cif` format.
# 2026-01-30 03:44:58,366 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:517] INFO runner.batch_inference: 1 generated jsons have been saved to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/.
# Found newly generated JSON: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/production_trajector-fc85670880b644938edceca207224fdc.json
# Renaming to: frame_15-without-msa.json
# Successfully renamed production_trajector-fc85670880b644938edceca207224fdc.json to frame_15-without-msa.json
# Processing: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/production_trajectory_frame_20.pdb
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-01-30 03:45:03,058 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:467] INFO runner.batch_inference: run tojson with input=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/production_trajectory_frame_20.pdb, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/, altloc=first, assembly_id=None
# 2026-01-30 03:45:03,059 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:487] INFO runner.batch_inference: will tojson jsons for 1 input files with `pdb` or `cif` format.
# 2026-01-30 03:45:11,088 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:517] INFO runner.batch_inference: 1 generated jsons have been saved to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/.
# Found newly generated JSON: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/production_trajector-e0243677948540b8928493872e7272b5.json
# Renaming to: frame_20-without-msa.json
# Successfully renamed production_trajector-e0243677948540b8928493872e7272b5.json to frame_20-without-msa.json
# Processing: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/production_trajectory_frame_25.pdb
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-01-30 03:45:15,801 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:467] INFO runner.batch_inference: run tojson with input=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/production_trajectory_frame_25.pdb, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/, altloc=first, assembly_id=None
# 2026-01-30 03:45:15,802 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:487] INFO runner.batch_inference: will tojson jsons for 1 input files with `pdb` or `cif` format.
# 2026-01-30 03:45:24,132 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:517] INFO runner.batch_inference: 1 generated jsons have been saved to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/.
# Found newly generated JSON: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/production_trajector-444df9c48c87470f82e0239c4520d27c.json
# Renaming to: frame_25-without-msa.json
# Successfully renamed production_trajector-444df9c48c87470f82e0239c4520d27c.json to frame_25-without-msa.json
# Processing: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/production_trajectory_frame_30.pdb
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-01-30 03:45:28,794 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:467] INFO runner.batch_inference: run tojson with input=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/production_trajectory_frame_30.pdb, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/, altloc=first, assembly_id=None
# 2026-01-30 03:45:28,795 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:487] INFO runner.batch_inference: will tojson jsons for 1 input files with `pdb` or `cif` format.
# 2026-01-30 03:45:36,805 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:517] INFO runner.batch_inference: 1 generated jsons have been saved to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/.
# Found newly generated JSON: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/production_trajector-2fe592ac59024b5d9dbbe4014e666571.json
# Renaming to: frame_30-without-msa.json
# Successfully renamed production_trajector-2fe592ac59024b5d9dbbe4014e666571.json to frame_30-without-msa.json

# %% [markdown]
# ## 4.b Then, lookup MSA history

# %%
import os

json_dir = '/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/'
output_dir = json_dir # Save output JSONs in the same directory

json_files = [f for f in os.listdir(json_dir) if f.endswith('.json')]

print(f"Found {len(json_files)} JSON files in {json_dir}:")
for json_file in json_files:
    print(json_file)
# Out:
# Found 7 JSON files in /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/:
# frame_00-without-msa.json
# frame_05-without-msa.json
# frame_10-without-msa.json
# frame_15-without-msa.json
# frame_20-without-msa.json
# frame_25-without-msa.json
# frame_30-without-msa.json

# %%
import os

json_dir = '/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/'
output_dir = json_dir # Save output JSONs in the same directory

json_files = [f for f in os.listdir(json_dir) if f.endswith('.json')]

for json_file in json_files:
    input_path = os.path.join(json_dir, json_file)
    print(f"Processing: {input_path}")
    # !protenix msa --input "{input_path}" --out_dir "{output_dir}"
# Out:
# Processing: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_00-without-msa.json
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-01-30 03:45:41,564 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:539] INFO runner.batch_inference: run msa with input=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_00-without-msa.json, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/
# 2026-01-30 03:45:41,566 [/usr/local/lib/python3.12/dist-packages/runner/msa_search.py:98] INFO runner.msa_search: starting to update msa result for seq 0 in /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_00-without-msa.json
# 2026-01-30 03:45:41,577 [/usr/local/lib/python3.12/dist-packages/protenix/web_service/colab_request_utils.py:209] INFO protenix.web_service.colab_request_utils: Msa server is running.
# COMPLETE: 100% 100/100 [00:00<00:00, 159.99it/s]Files downloaded and extracted successfully.
# COMPLETE: 100% 100/100 [00:02<00:00, 37.08it/s]
# 2026-01-30 03:45:44,468 [/usr/local/lib/python3.12/dist-packages/runner/msa_search.py:113] INFO runner.msa_search: update msa result success and save to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_00-without-msa-add-msa.json
# 2026-01-30 03:45:44,468 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:544] INFO runner.batch_inference: msa results have been update to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_00-without-msa-add-msa.json
# Processing: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_05-without-msa.json
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-01-30 03:45:49,097 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:539] INFO runner.batch_inference: run msa with input=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_05-without-msa.json, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/
# 2026-01-30 03:45:49,099 [/usr/local/lib/python3.12/dist-packages/runner/msa_search.py:98] INFO runner.msa_search: starting to update msa result for seq 0 in /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_05-without-msa.json
# 2026-01-30 03:45:49,105 [/usr/local/lib/python3.12/dist-packages/protenix/web_service/colab_request_utils.py:209] INFO protenix.web_service.colab_request_utils: Msa server is running.
# 2026-01-30 03:45:49,279 [/usr/local/lib/python3.12/dist-packages/runner/msa_search.py:113] INFO runner.msa_search: update msa result success and save to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_05-without-msa-add-msa.json
# 2026-01-30 03:45:49,279 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:544] INFO runner.batch_inference: msa results have been update to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_05-without-msa-add-msa.json
# Processing: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_10-without-msa.json
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-01-30 03:45:53,915 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:539] INFO runner.batch_inference: run msa with input=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_10-without-msa.json, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/
# 2026-01-30 03:45:53,918 [/usr/local/lib/python3.12/dist-packages/runner/msa_search.py:98] INFO runner.msa_search: starting to update msa result for seq 0 in /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_10-without-msa.json
# 2026-01-30 03:45:53,924 [/usr/local/lib/python3.12/dist-packages/protenix/web_service/colab_request_utils.py:209] INFO protenix.web_service.colab_request_utils: Msa server is running.
# 2026-01-30 03:45:54,106 [/usr/local/lib/python3.12/dist-packages/runner/msa_search.py:113] INFO runner.msa_search: update msa result success and save to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_10-without-msa-add-msa.json
# 2026-01-30 03:45:54,106 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:544] INFO runner.batch_inference: msa results have been update to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_10-without-msa-add-msa.json
# Processing: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_15-without-msa.json
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-01-30 03:45:58,873 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:539] INFO runner.batch_inference: run msa with input=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_15-without-msa.json, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/
# 2026-01-30 03:45:58,875 [/usr/local/lib/python3.12/dist-packages/runner/msa_search.py:98] INFO runner.msa_search: starting to update msa result for seq 0 in /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_15-without-msa.json
# 2026-01-30 03:45:58,884 [/usr/local/lib/python3.12/dist-packages/protenix/web_service/colab_request_utils.py:209] INFO protenix.web_service.colab_request_utils: Msa server is running.
# 2026-01-30 03:45:59,084 [/usr/local/lib/python3.12/dist-packages/runner/msa_search.py:113] INFO runner.msa_search: update msa result success and save to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_15-without-msa-add-msa.json
# 2026-01-30 03:45:59,084 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:544] INFO runner.batch_inference: msa results have been update to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_15-without-msa-add-msa.json
# Processing: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_20-without-msa.json
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-01-30 03:46:03,746 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:539] INFO runner.batch_inference: run msa with input=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_20-without-msa.json, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/
# 2026-01-30 03:46:03,748 [/usr/local/lib/python3.12/dist-packages/runner/msa_search.py:98] INFO runner.msa_search: starting to update msa result for seq 0 in /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_20-without-msa.json
# 2026-01-30 03:46:03,754 [/usr/local/lib/python3.12/dist-packages/protenix/web_service/colab_request_utils.py:209] INFO protenix.web_service.colab_request_utils: Msa server is running.
# 2026-01-30 03:46:03,929 [/usr/local/lib/python3.12/dist-packages/runner/msa_search.py:113] INFO runner.msa_search: update msa result success and save to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_20-without-msa-add-msa.json
# 2026-01-30 03:46:03,929 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:544] INFO runner.batch_inference: msa results have been update to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_20-without-msa-add-msa.json
# Processing: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_25-without-msa.json
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-01-30 03:46:08,595 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:539] INFO runner.batch_inference: run msa with input=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_25-without-msa.json, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/
# 2026-01-30 03:46:08,597 [/usr/local/lib/python3.12/dist-packages/runner/msa_search.py:98] INFO runner.msa_search: starting to update msa result for seq 0 in /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_25-without-msa.json
# 2026-01-30 03:46:08,604 [/usr/local/lib/python3.12/dist-packages/protenix/web_service/colab_request_utils.py:209] INFO protenix.web_service.colab_request_utils: Msa server is running.
# 2026-01-30 03:46:08,798 [/usr/local/lib/python3.12/dist-packages/runner/msa_search.py:113] INFO runner.msa_search: update msa result success and save to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_25-without-msa-add-msa.json
# 2026-01-30 03:46:08,798 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:544] INFO runner.batch_inference: msa results have been update to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_25-without-msa-add-msa.json
# Processing: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_30-without-msa.json
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-01-30 03:46:13,482 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:539] INFO runner.batch_inference: run msa with input=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_30-without-msa.json, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/
# 2026-01-30 03:46:13,485 [/usr/local/lib/python3.12/dist-packages/runner/msa_search.py:98] INFO runner.msa_search: starting to update msa result for seq 0 in /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_30-without-msa.json
# 2026-01-30 03:46:13,491 [/usr/local/lib/python3.12/dist-packages/protenix/web_service/colab_request_utils.py:209] INFO protenix.web_service.colab_request_utils: Msa server is running.
# 2026-01-30 03:46:13,685 [/usr/local/lib/python3.12/dist-packages/runner/msa_search.py:113] INFO runner.msa_search: update msa result success and save to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_30-without-msa-add-msa.json
# 2026-01-30 03:46:13,685 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:544] INFO runner.batch_inference: msa results have been update to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_30-without-msa-add-msa.json

# %% [markdown]
# ## 4.c Run "standard" inference

# %%
import os

json_dir = '/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/'
output_dir = json_dir # Save output JSONs in the same directory

json_files = [f for f in os.listdir(json_dir) if f.endswith('add-msa.json')]

print(f"Found {len(json_files)} JSON files in {json_dir}:")
for json_file in json_files:
    print(json_file)
# Out:
# Found 7 JSON files in /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/:
# frame_00-without-msa-add-msa.json
# frame_05-without-msa-add-msa.json
# frame_10-without-msa-add-msa.json
# frame_15-without-msa-add-msa.json
# frame_20-without-msa-add-msa.json
# frame_25-without-msa-add-msa.json
# frame_30-without-msa-add-msa.json

# %%
import os

json_dir = '/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/'
output_base_dir = json_dir # Base directory for all predictions

json_files = [f for f in os.listdir(json_dir) if f.endswith('add-msa.json')]

for json_file in json_files:
    input_path = os.path.join(json_dir, json_file)
    print(f"Processing: {input_path}")

    # Extract the base name (e.g., 'frame_00') from the json_file
    # It should be like 'frame_XX-without-msa-add-msa.json'
    base_name_with_suffix = json_file.split('-add-msa.json')[0] # 'frame_XX-without-msa'
    base_name_without_suffix = base_name_with_suffix.replace('-without-msa', '') # 'frame_XX'

    # Create a unique output directory for each prediction
    prediction_output_dir = os.path.join(output_base_dir, base_name_without_suffix)
    os.makedirs(prediction_output_dir, exist_ok=True)

    print(f"Saving predictions for {json_file} to: {prediction_output_dir}")
    # !protenix predict --input "{input_path}" --out_dir "{prediction_output_dir}"
# Out:
# Processing: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_00-without-msa-add-msa.json
# Saving predictions for frame_00-without-msa-add-msa.json to: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_00
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-01-30 03:46:18,413 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:383] INFO runner.batch_inference: run infer with input=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_00-without-msa-add-msa.json, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_00, sample=5
# 2026-01-30 03:46:18,413 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:408] INFO runner.batch_inference: Using the default params for inference for model protenix_base_default_v0.5.0: cycle=10, step=200, use_msa=True
# 2026-01-30 03:46:18,414 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:258] INFO runner.batch_inference: will infer with 1 jsons
# 2026-01-30 03:46:18,473 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:209] INFO runner.batch_inference: Inference by Protenix: model_size: base, with_feature: default, model_version: v0.5.0, dtype: bf16
# 2026-01-30 03:46:18,473 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:212] INFO runner.batch_inference: Triangle_multiplicative kernel: cuequivariance, Triangle_attention kernel: triattention
# 2026-01-30 03:46:18,473 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:215] INFO runner.batch_inference: enable_diffusion_shared_vars_cache: True, enable_efficient_fusion: True, enable_tf32: True
# 2026-01-30 03:46:18,473 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:231] INFO runner.inference: Downloading data cache from
#  https://af3-dev.tos-cn-beijing.volces.com/release_data/components.v20240608.cif.rdkit_mol.pkl... to /usr/local/lib/python3.12/dist-packages/release_data/ccd_cache/components.v20240608.cif.rdkit_mol.pkl
# [==============================] 100.0%
# 2026-01-30 03:46:34,705 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:231] INFO runner.inference: Downloading data cache from
#  https://af3-dev.tos-cn-beijing.volces.com/release_data/clusters-by-entity-40.txt... to /usr/local/lib/python3.12/dist-packages/release_data/ccd_cache/clusters-by-entity-40.txt
# [==============================] 100.0%
# 2026-01-30 03:46:40,772 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:242] INFO runner.inference: Downloading model checkpoint from
#  https://af3-dev.tos-cn-beijing.volces.com/release_model/protenix_base_default_v0.5.0.pt... to /usr/local/lib/python3.12/dist-packages/./release_data/checkpoint//protenix_base_default_v0.5.0.pt
# [==============================] 100.0%
# 2026-01-30 03:51:09,384 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Distributed environment: world size: 1, global rank: 0, local rank: 0
# 2026-01-30 03:51:09,384 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:87] INFO root: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2026-01-30 03:51:09,384 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:111] INFO root: Finished init ENV.
# train scheduler 16.0
# inference scheduler 16.0
# Diffusion Module has 16.0
# 2026-01-30 03:52:26,928 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Loading from /usr/local/lib/python3.12/dist-packages/./release_data/checkpoint//protenix_base_default_v0.5.0.pt, strict: True
# 2026-01-30 03:52:28,816 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Sampled key: module.input_embedder.atom_attention_encoder.linear_no_bias_ref_pos.weight
# 2026-01-30 03:52:28,965 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Finish loading checkpoint.
#   0% 0/1 [00:00<?, ?it/s]2026-01-30 03:52:28,978 [/usr/local/lib/python3.12/dist-packages/runner/msa_search.py:124] INFO runner.msa_search: do not need to update msa result, so return itself /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_00-without-msa-add-msa.json
# 2026-01-30 03:52:28,978 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:300] INFO runner.inference: Loading data from
# /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_00-without-msa-add-msa.json
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 2026-01-30 03:52:29,405 [/usr/local/lib/python3.12/dist-packages/protenix/data/infer_data_pipeline.py:246] INFO protenix.data.infer_data_pipeline: Featurizing production_trajector...
# 2026-01-30 03:52:40,283 [/usr/local/lib/python3.12/dist-packages/protenix/data/constraint_featurizer.py:386] INFO protenix.data.constraint_featurizer: Loaded constraint feature: #atom contact:0 #contact:0 #pocket:0
# 2026-01-30 03:52:50,170 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:327] INFO runner.inference: [Rank 0 (1/1)] production_trajector: N_asym 2, N_token 1654, N_atom 12791, N_msa 10026
# 2026-01-30 03:57:04,051 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:346] INFO runner.inference: [Rank 0] production_trajector succeeded. Model forward time: 253.8818576335907s.
# Results saved to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_00
# 2026-01-30 03:57:04,260 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:360] INFO runner.inference: [Rank 0] seed 101 succeeded. Total task time: 275.27927470207214s.
#
# 2026-01-30 03:57:04,261 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:364] INFO runner.inference: [Rank 0] job succeeded. Total job time: 275.28065371513367s.
#
# 100% 1/1 [04:35<00:00, 275.29s/it]
# Processing: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_05-without-msa-add-msa.json
# Saving predictions for frame_05-without-msa-add-msa.json to: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_05
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-01-30 03:57:11,388 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:383] INFO runner.batch_inference: run infer with input=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_05-without-msa-add-msa.json, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_05, sample=5
# 2026-01-30 03:57:11,389 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:408] INFO runner.batch_inference: Using the default params for inference for model protenix_base_default_v0.5.0: cycle=10, step=200, use_msa=True
# 2026-01-30 03:57:11,389 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:258] INFO runner.batch_inference: will infer with 1 jsons
# 2026-01-30 03:57:11,454 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:209] INFO runner.batch_inference: Inference by Protenix: model_size: base, with_feature: default, model_version: v0.5.0, dtype: bf16
# 2026-01-30 03:57:11,454 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:212] INFO runner.batch_inference: Triangle_multiplicative kernel: cuequivariance, Triangle_attention kernel: triattention
# 2026-01-30 03:57:11,454 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:215] INFO runner.batch_inference: enable_diffusion_shared_vars_cache: True, enable_efficient_fusion: True, enable_tf32: True
# 2026-01-30 03:57:11,454 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Distributed environment: world size: 1, global rank: 0, local rank: 0
# 2026-01-30 03:57:11,454 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:87] INFO root: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2026-01-30 03:57:11,454 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:111] INFO root: Finished init ENV.
# train scheduler 16.0
# inference scheduler 16.0
# Diffusion Module has 16.0
# 2026-01-30 03:58:32,494 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Loading from /usr/local/lib/python3.12/dist-packages/./release_data/checkpoint//protenix_base_default_v0.5.0.pt, strict: True
# 2026-01-30 03:58:34,317 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Sampled key: module.input_embedder.atom_attention_encoder.linear_no_bias_ref_pos.weight
# 2026-01-30 03:58:34,465 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Finish loading checkpoint.
#   0% 0/1 [00:00<?, ?it/s]2026-01-30 03:58:34,502 [/usr/local/lib/python3.12/dist-packages/runner/msa_search.py:124] INFO runner.msa_search: do not need to update msa result, so return itself /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_05-without-msa-add-msa.json
# 2026-01-30 03:58:34,502 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:300] INFO runner.inference: Loading data from
# /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_05-without-msa-add-msa.json
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 2026-01-30 03:58:34,878 [/usr/local/lib/python3.12/dist-packages/protenix/data/infer_data_pipeline.py:246] INFO protenix.data.infer_data_pipeline: Featurizing production_trajector...
# 2026-01-30 03:58:45,706 [/usr/local/lib/python3.12/dist-packages/protenix/data/constraint_featurizer.py:386] INFO protenix.data.constraint_featurizer: Loaded constraint feature: #atom contact:0 #contact:0 #pocket:0
# 2026-01-30 03:58:55,660 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:327] INFO runner.inference: [Rank 0 (1/1)] production_trajector: N_asym 2, N_token 1654, N_atom 12791, N_msa 10026
# 2026-01-30 04:02:44,426 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:346] INFO runner.inference: [Rank 0] production_trajector succeeded. Model forward time: 228.76635718345642s.
# Results saved to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_05
# 2026-01-30 04:02:44,620 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:360] INFO runner.inference: [Rank 0] seed 101 succeeded. Total task time: 250.11528301239014s.
#
# 2026-01-30 04:02:44,620 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:364] INFO runner.inference: [Rank 0] job succeeded. Total job time: 250.1165680885315s.
#
# 100% 1/1 [04:10<00:00, 250.12s/it]
# Processing: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_10-without-msa-add-msa.json
# Saving predictions for frame_10-without-msa-add-msa.json to: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_10
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-01-30 04:02:51,722 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:383] INFO runner.batch_inference: run infer with input=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_10-without-msa-add-msa.json, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_10, sample=5
# 2026-01-30 04:02:51,723 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:408] INFO runner.batch_inference: Using the default params for inference for model protenix_base_default_v0.5.0: cycle=10, step=200, use_msa=True
# 2026-01-30 04:02:51,723 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:258] INFO runner.batch_inference: will infer with 1 jsons
# 2026-01-30 04:02:51,788 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:209] INFO runner.batch_inference: Inference by Protenix: model_size: base, with_feature: default, model_version: v0.5.0, dtype: bf16
# 2026-01-30 04:02:51,788 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:212] INFO runner.batch_inference: Triangle_multiplicative kernel: cuequivariance, Triangle_attention kernel: triattention
# 2026-01-30 04:02:51,788 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:215] INFO runner.batch_inference: enable_diffusion_shared_vars_cache: True, enable_efficient_fusion: True, enable_tf32: True
# 2026-01-30 04:02:51,788 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Distributed environment: world size: 1, global rank: 0, local rank: 0
# 2026-01-30 04:02:51,788 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:87] INFO root: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2026-01-30 04:02:51,789 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:111] INFO root: Finished init ENV.
# train scheduler 16.0
# inference scheduler 16.0
# Diffusion Module has 16.0
# 2026-01-30 04:04:12,826 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Loading from /usr/local/lib/python3.12/dist-packages/./release_data/checkpoint//protenix_base_default_v0.5.0.pt, strict: True
# 2026-01-30 04:04:14,642 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Sampled key: module.input_embedder.atom_attention_encoder.linear_no_bias_ref_pos.weight
# 2026-01-30 04:04:14,785 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Finish loading checkpoint.
#   0% 0/1 [00:00<?, ?it/s]2026-01-30 04:04:14,798 [/usr/local/lib/python3.12/dist-packages/runner/msa_search.py:124] INFO runner.msa_search: do not need to update msa result, so return itself /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_10-without-msa-add-msa.json
# 2026-01-30 04:04:14,798 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:300] INFO runner.inference: Loading data from
# /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_10-without-msa-add-msa.json
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 2026-01-30 04:04:15,266 [/usr/local/lib/python3.12/dist-packages/protenix/data/infer_data_pipeline.py:246] INFO protenix.data.infer_data_pipeline: Featurizing production_trajector...
# 2026-01-30 04:04:26,059 [/usr/local/lib/python3.12/dist-packages/protenix/data/constraint_featurizer.py:386] INFO protenix.data.constraint_featurizer: Loaded constraint feature: #atom contact:0 #contact:0 #pocket:0
# 2026-01-30 04:04:36,095 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:327] INFO runner.inference: [Rank 0 (1/1)] production_trajector: N_asym 2, N_token 1654, N_atom 12791, N_msa 10026
# 2026-01-30 04:08:25,024 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:346] INFO runner.inference: [Rank 0] production_trajector succeeded. Model forward time: 228.9289779663086s.
# Results saved to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_10
# 2026-01-30 04:08:25,229 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:360] INFO runner.inference: [Rank 0] seed 101 succeeded. Total task time: 250.4278542995453s.
#
# 2026-01-30 04:08:25,229 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:364] INFO runner.inference: [Rank 0] job succeeded. Total job time: 250.42913508415222s.
#
# 100% 1/1 [04:10<00:00, 250.43s/it]
# Processing: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_15-without-msa-add-msa.json
# Saving predictions for frame_15-without-msa-add-msa.json to: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_15
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-01-30 04:08:32,296 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:383] INFO runner.batch_inference: run infer with input=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_15-without-msa-add-msa.json, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_15, sample=5
# 2026-01-30 04:08:32,296 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:408] INFO runner.batch_inference: Using the default params for inference for model protenix_base_default_v0.5.0: cycle=10, step=200, use_msa=True
# 2026-01-30 04:08:32,297 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:258] INFO runner.batch_inference: will infer with 1 jsons
# 2026-01-30 04:08:32,361 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:209] INFO runner.batch_inference: Inference by Protenix: model_size: base, with_feature: default, model_version: v0.5.0, dtype: bf16
# 2026-01-30 04:08:32,361 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:212] INFO runner.batch_inference: Triangle_multiplicative kernel: cuequivariance, Triangle_attention kernel: triattention
# 2026-01-30 04:08:32,361 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:215] INFO runner.batch_inference: enable_diffusion_shared_vars_cache: True, enable_efficient_fusion: True, enable_tf32: True
# 2026-01-30 04:08:32,361 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Distributed environment: world size: 1, global rank: 0, local rank: 0
# 2026-01-30 04:08:32,361 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:87] INFO root: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2026-01-30 04:08:32,361 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:111] INFO root: Finished init ENV.
# train scheduler 16.0
# inference scheduler 16.0
# Diffusion Module has 16.0
# 2026-01-30 04:09:53,592 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Loading from /usr/local/lib/python3.12/dist-packages/./release_data/checkpoint//protenix_base_default_v0.5.0.pt, strict: True
# 2026-01-30 04:09:55,424 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Sampled key: module.input_embedder.atom_attention_encoder.linear_no_bias_ref_pos.weight
# 2026-01-30 04:09:55,570 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Finish loading checkpoint.
#   0% 0/1 [00:00<?, ?it/s]2026-01-30 04:09:55,583 [/usr/local/lib/python3.12/dist-packages/runner/msa_search.py:124] INFO runner.msa_search: do not need to update msa result, so return itself /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_15-without-msa-add-msa.json
# 2026-01-30 04:09:55,583 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:300] INFO runner.inference: Loading data from
# /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_15-without-msa-add-msa.json
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 2026-01-30 04:09:56,078 [/usr/local/lib/python3.12/dist-packages/protenix/data/infer_data_pipeline.py:246] INFO protenix.data.infer_data_pipeline: Featurizing production_trajector...
# 2026-01-30 04:10:07,002 [/usr/local/lib/python3.12/dist-packages/protenix/data/constraint_featurizer.py:386] INFO protenix.data.constraint_featurizer: Loaded constraint feature: #atom contact:0 #contact:0 #pocket:0
# 2026-01-30 04:10:17,040 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:327] INFO runner.inference: [Rank 0 (1/1)] production_trajector: N_asym 2, N_token 1654, N_atom 12791, N_msa 10026
# 2026-01-30 04:14:06,041 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:346] INFO runner.inference: [Rank 0] production_trajector succeeded. Model forward time: 229.00097751617432s.
# Results saved to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_15
# 2026-01-30 04:14:06,248 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:360] INFO runner.inference: [Rank 0] seed 101 succeeded. Total task time: 250.66217422485352s.
#
# 2026-01-30 04:14:06,249 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:364] INFO runner.inference: [Rank 0] job succeeded. Total job time: 250.66377544403076s.
#
# 100% 1/1 [04:10<00:00, 250.67s/it]
# Processing: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_20-without-msa-add-msa.json
# Saving predictions for frame_20-without-msa-add-msa.json to: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_20
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-01-30 04:14:13,391 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:383] INFO runner.batch_inference: run infer with input=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_20-without-msa-add-msa.json, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_20, sample=5
# 2026-01-30 04:14:13,391 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:408] INFO runner.batch_inference: Using the default params for inference for model protenix_base_default_v0.5.0: cycle=10, step=200, use_msa=True
# 2026-01-30 04:14:13,392 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:258] INFO runner.batch_inference: will infer with 1 jsons
# 2026-01-30 04:14:13,457 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:209] INFO runner.batch_inference: Inference by Protenix: model_size: base, with_feature: default, model_version: v0.5.0, dtype: bf16
# 2026-01-30 04:14:13,457 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:212] INFO runner.batch_inference: Triangle_multiplicative kernel: cuequivariance, Triangle_attention kernel: triattention
# 2026-01-30 04:14:13,457 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:215] INFO runner.batch_inference: enable_diffusion_shared_vars_cache: True, enable_efficient_fusion: True, enable_tf32: True
# 2026-01-30 04:14:13,457 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Distributed environment: world size: 1, global rank: 0, local rank: 0
# 2026-01-30 04:14:13,457 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:87] INFO root: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2026-01-30 04:14:13,457 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:111] INFO root: Finished init ENV.
# train scheduler 16.0
# inference scheduler 16.0
# Diffusion Module has 16.0
# 2026-01-30 04:15:34,854 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Loading from /usr/local/lib/python3.12/dist-packages/./release_data/checkpoint//protenix_base_default_v0.5.0.pt, strict: True
# 2026-01-30 04:15:36,681 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Sampled key: module.input_embedder.atom_attention_encoder.linear_no_bias_ref_pos.weight
# 2026-01-30 04:15:36,829 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Finish loading checkpoint.
#   0% 0/1 [00:00<?, ?it/s]2026-01-30 04:15:36,842 [/usr/local/lib/python3.12/dist-packages/runner/msa_search.py:124] INFO runner.msa_search: do not need to update msa result, so return itself /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_20-without-msa-add-msa.json
# 2026-01-30 04:15:36,842 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:300] INFO runner.inference: Loading data from
# /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_20-without-msa-add-msa.json
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 2026-01-30 04:15:37,385 [/usr/local/lib/python3.12/dist-packages/protenix/data/infer_data_pipeline.py:246] INFO protenix.data.infer_data_pipeline: Featurizing production_trajector...
# 2026-01-30 04:15:48,280 [/usr/local/lib/python3.12/dist-packages/protenix/data/constraint_featurizer.py:386] INFO protenix.data.constraint_featurizer: Loaded constraint feature: #atom contact:0 #contact:0 #pocket:0
# 2026-01-30 04:15:58,245 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:327] INFO runner.inference: [Rank 0 (1/1)] production_trajector: N_asym 2, N_token 1654, N_atom 12791, N_msa 10026
# 2026-01-30 04:19:47,090 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:346] INFO runner.inference: [Rank 0] production_trajector succeeded. Model forward time: 228.84580373764038s.
# Results saved to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_20
# 2026-01-30 04:19:47,308 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:360] INFO runner.inference: [Rank 0] seed 101 succeeded. Total task time: 250.4620440006256s.
#
# 2026-01-30 04:19:47,308 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:364] INFO runner.inference: [Rank 0] job succeeded. Total job time: 250.463294506073s.
#
# 100% 1/1 [04:10<00:00, 250.47s/it]
# Processing: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_25-without-msa-add-msa.json
# Saving predictions for frame_25-without-msa-add-msa.json to: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_25
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-01-30 04:19:54,457 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:383] INFO runner.batch_inference: run infer with input=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_25-without-msa-add-msa.json, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_25, sample=5
# 2026-01-30 04:19:54,457 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:408] INFO runner.batch_inference: Using the default params for inference for model protenix_base_default_v0.5.0: cycle=10, step=200, use_msa=True
# 2026-01-30 04:19:54,458 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:258] INFO runner.batch_inference: will infer with 1 jsons
# 2026-01-30 04:19:54,523 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:209] INFO runner.batch_inference: Inference by Protenix: model_size: base, with_feature: default, model_version: v0.5.0, dtype: bf16
# 2026-01-30 04:19:54,523 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:212] INFO runner.batch_inference: Triangle_multiplicative kernel: cuequivariance, Triangle_attention kernel: triattention
# 2026-01-30 04:19:54,523 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:215] INFO runner.batch_inference: enable_diffusion_shared_vars_cache: True, enable_efficient_fusion: True, enable_tf32: True
# 2026-01-30 04:19:54,523 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Distributed environment: world size: 1, global rank: 0, local rank: 0
# 2026-01-30 04:19:54,523 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:87] INFO root: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2026-01-30 04:19:54,524 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:111] INFO root: Finished init ENV.
# train scheduler 16.0
# inference scheduler 16.0
# Diffusion Module has 16.0
# 2026-01-30 04:21:15,887 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Loading from /usr/local/lib/python3.12/dist-packages/./release_data/checkpoint//protenix_base_default_v0.5.0.pt, strict: True
# 2026-01-30 04:21:17,706 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Sampled key: module.input_embedder.atom_attention_encoder.linear_no_bias_ref_pos.weight
# 2026-01-30 04:21:17,854 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Finish loading checkpoint.
#   0% 0/1 [00:00<?, ?it/s]2026-01-30 04:21:17,867 [/usr/local/lib/python3.12/dist-packages/runner/msa_search.py:124] INFO runner.msa_search: do not need to update msa result, so return itself /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_25-without-msa-add-msa.json
# 2026-01-30 04:21:17,867 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:300] INFO runner.inference: Loading data from
# /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_25-without-msa-add-msa.json
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 2026-01-30 04:21:18,397 [/usr/local/lib/python3.12/dist-packages/protenix/data/infer_data_pipeline.py:246] INFO protenix.data.infer_data_pipeline: Featurizing production_trajector...
# 2026-01-30 04:21:29,166 [/usr/local/lib/python3.12/dist-packages/protenix/data/constraint_featurizer.py:386] INFO protenix.data.constraint_featurizer: Loaded constraint feature: #atom contact:0 #contact:0 #pocket:0
# 2026-01-30 04:21:39,180 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:327] INFO runner.inference: [Rank 0 (1/1)] production_trajector: N_asym 2, N_token 1654, N_atom 12791, N_msa 10026
# 2026-01-30 04:25:28,118 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:346] INFO runner.inference: [Rank 0] production_trajector succeeded. Model forward time: 228.93745636940002s.
# Results saved to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_25
# 2026-01-30 04:25:28,326 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:360] INFO runner.inference: [Rank 0] seed 101 succeeded. Total task time: 250.4561231136322s.
#
# 2026-01-30 04:25:28,326 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:364] INFO runner.inference: [Rank 0] job succeeded. Total job time: 250.45733428001404s.
#
# 100% 1/1 [04:10<00:00, 250.46s/it]
# Processing: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_30-without-msa-add-msa.json
# Saving predictions for frame_30-without-msa-add-msa.json to: /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_30
# Try to find the ccd cache data in the code directory for inference.
# /usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py:61: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# 2026-01-30 04:25:35,445 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:383] INFO runner.batch_inference: run infer with input=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_30-without-msa-add-msa.json, out_dir=/content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_30, sample=5
# 2026-01-30 04:25:35,445 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:408] INFO runner.batch_inference: Using the default params for inference for model protenix_base_default_v0.5.0: cycle=10, step=200, use_msa=True
# 2026-01-30 04:25:35,446 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:258] INFO runner.batch_inference: will infer with 1 jsons
# 2026-01-30 04:25:35,510 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:209] INFO runner.batch_inference: Inference by Protenix: model_size: base, with_feature: default, model_version: v0.5.0, dtype: bf16
# 2026-01-30 04:25:35,511 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:212] INFO runner.batch_inference: Triangle_multiplicative kernel: cuequivariance, Triangle_attention kernel: triattention
# 2026-01-30 04:25:35,511 [/usr/local/lib/python3.12/dist-packages/runner/batch_inference.py:215] INFO runner.batch_inference: enable_diffusion_shared_vars_cache: True, enable_efficient_fusion: True, enable_tf32: True
# 2026-01-30 04:25:35,511 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Distributed environment: world size: 1, global rank: 0, local rank: 0
# 2026-01-30 04:25:35,511 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:87] INFO root: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2026-01-30 04:25:35,511 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:111] INFO root: Finished init ENV.
# train scheduler 16.0
# inference scheduler 16.0
# Diffusion Module has 16.0
# 2026-01-30 04:26:56,614 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Loading from /usr/local/lib/python3.12/dist-packages/./release_data/checkpoint//protenix_base_default_v0.5.0.pt, strict: True
# 2026-01-30 04:26:58,431 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Sampled key: module.input_embedder.atom_attention_encoder.linear_no_bias_ref_pos.weight
# 2026-01-30 04:26:58,577 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:183] INFO runner.inference: Finish loading checkpoint.
#   0% 0/1 [00:00<?, ?it/s]2026-01-30 04:26:58,590 [/usr/local/lib/python3.12/dist-packages/runner/msa_search.py:124] INFO runner.msa_search: do not need to update msa result, so return itself /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_30-without-msa-add-msa.json
# 2026-01-30 04:26:58,590 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:300] INFO runner.inference: Loading data from
# /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_30-without-msa-add-msa.json
# /usr/local/lib/python3.12/dist-packages/torch/utils/data/dataloader.py:626: UserWarning: This DataLoader will create 16 worker processes in total. Our suggested max number of worker in current system is 12, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# 2026-01-30 04:26:59,133 [/usr/local/lib/python3.12/dist-packages/protenix/data/infer_data_pipeline.py:246] INFO protenix.data.infer_data_pipeline: Featurizing production_trajector...
# 2026-01-30 04:27:09,955 [/usr/local/lib/python3.12/dist-packages/protenix/data/constraint_featurizer.py:386] INFO protenix.data.constraint_featurizer: Loaded constraint feature: #atom contact:0 #contact:0 #pocket:0
# 2026-01-30 04:27:19,965 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:327] INFO runner.inference: [Rank 0 (1/1)] production_trajector: N_asym 2, N_token 1654, N_atom 12791, N_msa 10026
# 2026-01-30 04:31:08,936 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:346] INFO runner.inference: [Rank 0] production_trajector succeeded. Model forward time: 228.9712233543396s.
# Results saved to /content/drive/MyDrive/colab_cache/afmfold-data/AVB3/frame_30
# 2026-01-30 04:31:09,172 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:360] INFO runner.inference: [Rank 0] seed 101 succeeded. Total task time: 250.57912373542786s.
#
# 2026-01-30 04:31:09,172 [/usr/local/lib/python3.12/dist-packages/runner/inference.py:364] INFO runner.inference: [Rank 0] job succeeded. Total job time: 250.58035588264465s.
#
# 100% 1/1 [04:10<00:00, 250.59s/it]

# %% [markdown]
# ## 5. MD candidates -> CVs -> pseudo-AFM images
# This section assumes all PDBs share the same residue order/topology (trim to a common reference first).

# %%
# !pip install numpy mdtraj

# %%
# --- MD candidates pipeline (folder of PDBs) ---
# Prereqs:
# 1) All PDBs must have identical atom/residue ordering (trim/renumber to a common reference).
# 2) Domain indices must match the trimmed reference (see storage/domain/integrin/*.npy).

import os
import glob
import numpy as np
import mdtraj as md

from afmfold.domain import get_domain_pairs, compute_domain_distance

# Paths
pdb_dir = "/content/drive/MyDrive/colab_cache/afmfold-data/MD-candidates/AVB3"
out_dir = "/content/drive/MyDrive/colab_cache/afmfold-data/MD-candidates/AVB3_outputs"
os.makedirs(out_dir, exist_ok=True)

# Collect PDBs
pdb_files = sorted(glob.glob(os.path.join(pdb_dir, "*.pdb")))
if not pdb_files:
    raise FileNotFoundError(f"No PDBs found in {pdb_dir}")

print(f"Found {len(pdb_files)} PDBs")

# Load trajectory from PDBs (assumes identical topology)
traj = md.load(pdb_files)

# Save combined trajectory (optional)
traj_pdb = os.path.join(out_dir, "avb3_candidates.pdb")
traj_dcd = os.path.join(out_dir, "avb3_candidates.dcd")
traj.save_pdb(traj_pdb)
traj.save_dcd(traj_dcd)
print("Saved trajectory:", traj_pdb, traj_dcd)

# Compute CVs (inter-domain distances) in Angstrom
name = "integrin"
domain_pairs = get_domain_pairs(name)

domain_distance = np.zeros((len(traj), len(domain_pairs)))
for i, (d1, d2) in enumerate(domain_pairs):
    domain_distance[:, i] = compute_domain_distance(traj, d1, d2).ravel()

domain_distance *= 10.0  # nm -> Å

cv_path = os.path.join(out_dir, "avb3_candidates_distance.npy")
np.save(cv_path, domain_distance)
print("Saved CVs:", cv_path)

# Generate pseudo-AFM images
# These defaults match AFM-Fold-ish settings; adjust to your AFM setup.
img_dir = os.path.join(out_dir, "pseudo_afm")
os.makedirs(img_dir, exist_ok=True)

# You can reduce epochs/dataset-size for a quick test
# !python /content/drive/MyDrive/colab_cache/afmfold/scripts/generate_images.py \
    --save-dir "{img_dir}" \
    --pdb-path "{traj_pdb}" \
    --dcd-path "{traj_dcd}" \
    --distance-path "{cv_path}" \
    --width 35 --height 35 \
    --resolution-nm 0.98 \
    --min-tip-radius 2.0 --max-tip-radius 6.0 \
    --noise-nm 0.5 \
    --epochs 1 \
    --dataset-size 1000 \
    --device cuda
